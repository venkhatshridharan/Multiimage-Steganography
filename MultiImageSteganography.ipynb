# %%
pip install torchviz
# Out:
# Collecting torchviz
#   Downloading torchviz-0.0.2.tar.gz (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torchviz) (2.2.1+cu121)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from torchviz) (0.20.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->torchviz)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 44.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->torchviz)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 51.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->torchviz)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 77.1 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->torchviz)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 879.8 kB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->torchviz)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.3 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->torchviz)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.7 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->torchviz)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.4 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->torchviz)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 5.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->torchviz)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch->torchviz)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.3 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->torchviz)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->torchviz) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->torchviz)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 47.8 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torchviz) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->torchviz) (1.3.0)
# Building wheels for collected packages: torchviz
#   Building wheel for torchviz (setup.py) ... done
#   Created wheel for torchviz: filename=torchviz-0.0.2-py3-none-any.whl size=4132 sha256=f5d53a128df4e2326f017e26cf960c8deb0f96e8d3123b1e781ee12ed25a2d86
#   Stored in directory: /root/.cache/pip/wheels/4c/97/88/a02973217949e0db0c9f4346d154085f4725f99c4f15a87094
# Successfully built torchviz
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchviz
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 torchviz-0.0.2

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
import torchvision
import matplotlib.pyplot as plt
from PIL import Image
from torchviz import make_dot

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = '/content/dataset'
train_csv = 'train_dataset.csv'
valid_csv = 'validation_dataset.csv'
train_folder = 'train/'
validation_folder = 'valid/'

# %%
# !unzip /content/drive/MyDrive/dataset.zip
# Out:
# Archive:  /content/drive/MyDrive/dataset.zip
#    creating: dataset/train/
#   inflating: dataset/train/n01443537_102.JPEG
#   inflating: dataset/train/n01443537_217.JPEG
#   inflating: dataset/train/n01443537_225.JPEG
#   inflating: dataset/train/n01443537_242.JPEG
#   inflating: dataset/train/n01443537_359.JPEG
#   inflating: dataset/train/n01443537_367.JPEG
#   inflating: dataset/train/n01443537_488.JPEG
#   inflating: dataset/train/n01443537_490.JPEG
#   inflating: dataset/train/n01443537_86.JPEG
#   inflating: dataset/train/n01443537_88.JPEG
#   inflating: dataset/train/n01629819_120.JPEG
#   inflating: dataset/train/n01629819_180.JPEG
#   inflating: dataset/train/n01629819_181.JPEG
#   inflating: dataset/train/n01629819_268.JPEG
#   inflating: dataset/train/n01629819_343.JPEG
#   inflating: dataset/train/n01629819_377.JPEG
#   inflating: dataset/train/n01629819_379.JPEG
#   inflating: dataset/train/n01629819_434.JPEG
#   inflating: dataset/train/n01629819_441.JPEG
#   inflating: dataset/train/n01629819_70.JPEG
#   inflating: dataset/train/n01641577_144.JPEG
#   inflating: dataset/train/n01641577_160.JPEG
#   inflating: dataset/train/n01641577_218.JPEG
#   inflating: dataset/train/n01641577_247.JPEG
#   inflating: dataset/train/n01641577_289.JPEG
#   inflating: dataset/train/n01641577_293.JPEG
#   inflating: dataset/train/n01641577_350.JPEG
#   inflating: dataset/train/n01641577_389.JPEG
#   inflating: dataset/train/n01641577_461.JPEG
#   inflating: dataset/train/n01641577_7.JPEG
#   inflating: dataset/train/n01644900_18.JPEG
#   inflating: dataset/train/n01644900_262.JPEG
#   inflating: dataset/train/n01644900_321.JPEG
#   inflating: dataset/train/n01644900_357.JPEG
#   inflating: dataset/train/n01644900_420.JPEG
#   inflating: dataset/train/n01644900_455.JPEG
#   inflating: dataset/train/n01644900_465.JPEG
#   inflating: dataset/train/n01644900_466.JPEG
#   inflating: dataset/train/n01644900_47.JPEG
#   inflating: dataset/train/n01644900_60.JPEG
#   inflating: dataset/train/n01698640_148.JPEG
#   inflating: dataset/train/n01698640_225.JPEG
#   inflating: dataset/train/n01698640_300.JPEG
#   inflating: dataset/train/n01698640_314.JPEG
#   inflating: dataset/train/n01698640_328.JPEG
#   inflating: dataset/train/n01698640_372.JPEG
#   inflating: dataset/train/n01698640_379.JPEG
#   inflating: dataset/train/n01698640_395.JPEG
#   inflating: dataset/train/n01698640_438.JPEG
#   inflating: dataset/train/n01698640_67.JPEG
#   inflating: dataset/train/n01742172_152.JPEG
#   inflating: dataset/train/n01742172_153.JPEG
#   inflating: dataset/train/n01742172_163.JPEG
#   inflating: dataset/train/n01742172_17.JPEG
#   inflating: dataset/train/n01742172_177.JPEG
#   inflating: dataset/train/n01742172_253.JPEG
#   inflating: dataset/train/n01742172_327.JPEG
#   inflating: dataset/train/n01742172_361.JPEG
#   inflating: dataset/train/n01742172_377.JPEG
#   inflating: dataset/train/n01742172_87.JPEG
#   inflating: dataset/train/n01768244_102.JPEG
#   inflating: dataset/train/n01768244_190.JPEG
#   inflating: dataset/train/n01768244_205.JPEG
#   inflating: dataset/train/n01768244_216.JPEG
#   inflating: dataset/train/n01768244_23.JPEG
#   inflating: dataset/train/n01768244_251.JPEG
#   inflating: dataset/train/n01768244_37.JPEG
#   inflating: dataset/train/n01768244_452.JPEG
#   inflating: dataset/train/n01768244_481.JPEG
#   inflating: dataset/train/n01768244_99.JPEG
#   inflating: dataset/train/n01770393_114.JPEG
#   inflating: dataset/train/n01770393_116.JPEG
#   inflating: dataset/train/n01770393_175.JPEG
#   inflating: dataset/train/n01770393_320.JPEG
#   inflating: dataset/train/n01770393_322.JPEG
#   inflating: dataset/train/n01770393_334.JPEG
#   inflating: dataset/train/n01770393_366.JPEG
#   inflating: dataset/train/n01770393_37.JPEG
#   inflating: dataset/train/n01770393_371.JPEG
#   inflating: dataset/train/n01770393_390.JPEG
#   inflating: dataset/train/n01774384_139.JPEG
#   inflating: dataset/train/n01774384_150.JPEG
#   inflating: dataset/train/n01774384_185.JPEG
#   inflating: dataset/train/n01774384_242.JPEG
#   inflating: dataset/train/n01774384_289.JPEG
#   inflating: dataset/train/n01774384_370.JPEG
#   inflating: dataset/train/n01774384_377.JPEG
#   inflating: dataset/train/n01774384_40.JPEG
#   inflating: dataset/train/n01774384_474.JPEG
#   inflating: dataset/train/n01774384_64.JPEG
#   inflating: dataset/train/n01774750_146.JPEG
#   inflating: dataset/train/n01774750_196.JPEG
#   inflating: dataset/train/n01774750_26.JPEG
#   inflating: dataset/train/n01774750_281.JPEG
#   inflating: dataset/train/n01774750_283.JPEG
#   inflating: dataset/train/n01774750_3.JPEG
#   inflating: dataset/train/n01774750_305.JPEG
#   inflating: dataset/train/n01774750_397.JPEG
#   inflating: dataset/train/n01774750_4.JPEG
#   inflating: dataset/train/n01774750_9.JPEG
#   inflating: dataset/train/n01784675_172.JPEG
#   inflating: dataset/train/n01784675_289.JPEG
#   inflating: dataset/train/n01784675_345.JPEG
#   inflating: dataset/train/n01784675_346.JPEG
#   inflating: dataset/train/n01784675_347.JPEG
#   inflating: dataset/train/n01784675_374.JPEG
#   inflating: dataset/train/n01784675_380.JPEG
#   inflating: dataset/train/n01784675_435.JPEG
#   inflating: dataset/train/n01784675_453.JPEG
#   inflating: dataset/train/n01784675_490.JPEG
#   inflating: dataset/train/n01855672_109.JPEG
#   inflating: dataset/train/n01855672_153.JPEG
#   inflating: dataset/train/n01855672_264.JPEG
#   inflating: dataset/train/n01855672_370.JPEG
#   inflating: dataset/train/n01855672_396.JPEG
#   inflating: dataset/train/n01855672_413.JPEG
#   inflating: dataset/train/n01855672_48.JPEG
#   inflating: dataset/train/n01855672_84.JPEG
#   inflating: dataset/train/n01855672_9.JPEG
#   inflating: dataset/train/n01855672_98.JPEG
#   inflating: dataset/train/n01882714_0.JPEG
#   inflating: dataset/train/n01882714_120.JPEG
#   inflating: dataset/train/n01882714_131.JPEG
#   inflating: dataset/train/n01882714_201.JPEG
#   inflating: dataset/train/n01882714_297.JPEG
#   inflating: dataset/train/n01882714_348.JPEG
#   inflating: dataset/train/n01882714_398.JPEG
#   inflating: dataset/train/n01882714_41.JPEG
#   inflating: dataset/train/n01882714_411.JPEG
#   inflating: dataset/train/n01882714_431.JPEG
#   inflating: dataset/train/n01910747_192.JPEG
#   inflating: dataset/train/n01910747_261.JPEG
#   inflating: dataset/train/n01910747_305.JPEG
#   inflating: dataset/train/n01910747_318.JPEG
#   inflating: dataset/train/n01910747_38.JPEG
#   inflating: dataset/train/n01910747_424.JPEG
#   inflating: dataset/train/n01910747_466.JPEG
#   inflating: dataset/train/n01910747_473.JPEG
#   inflating: dataset/train/n01910747_5.JPEG
#   inflating: dataset/train/n01910747_51.JPEG
#   inflating: dataset/train/n01917289_111.JPEG
#   inflating: dataset/train/n01917289_186.JPEG
#   inflating: dataset/train/n01917289_219.JPEG
#   inflating: dataset/train/n01917289_262.JPEG
#   inflating: dataset/train/n01917289_320.JPEG
#   inflating: dataset/train/n01917289_332.JPEG
#   inflating: dataset/train/n01917289_443.JPEG
#   inflating: dataset/train/n01917289_65.JPEG
#   inflating: dataset/train/n01917289_83.JPEG
#   inflating: dataset/train/n01917289_97.JPEG
#   inflating: dataset/train/n01944390_119.JPEG
#   inflating: dataset/train/n01944390_178.JPEG
#   inflating: dataset/train/n01944390_196.JPEG
#   inflating: dataset/train/n01944390_214.JPEG
#   inflating: dataset/train/n01944390_23.JPEG
#   inflating: dataset/train/n01944390_277.JPEG
#   inflating: dataset/train/n01944390_289.JPEG
#   inflating: dataset/train/n01944390_304.JPEG
#   inflating: dataset/train/n01944390_37.JPEG
#   inflating: dataset/train/n01944390_419.JPEG
#   inflating: dataset/train/n01945685_1.JPEG
#   inflating: dataset/train/n01945685_103.JPEG
#   inflating: dataset/train/n01945685_159.JPEG
#   inflating: dataset/train/n01945685_17.JPEG
#   inflating: dataset/train/n01945685_193.JPEG
#   inflating: dataset/train/n01945685_348.JPEG
#   inflating: dataset/train/n01945685_363.JPEG
#   inflating: dataset/train/n01945685_389.JPEG
#   inflating: dataset/train/n01945685_394.JPEG
#   inflating: dataset/train/n01945685_435.JPEG
#   inflating: dataset/train/n01950731_162.JPEG
#   inflating: dataset/train/n01950731_167.JPEG
#   inflating: dataset/train/n01950731_186.JPEG
#   inflating: dataset/train/n01950731_203.JPEG
#   inflating: dataset/train/n01950731_290.JPEG
#   inflating: dataset/train/n01950731_306.JPEG
#   inflating: dataset/train/n01950731_4.JPEG
#   inflating: dataset/train/n01950731_403.JPEG
#   inflating: dataset/train/n01950731_409.JPEG
#   inflating: dataset/train/n01950731_497.JPEG
#   inflating: dataset/train/n01983481_219.JPEG
#   inflating: dataset/train/n01983481_234.JPEG
#   inflating: dataset/train/n01983481_27.JPEG
#   inflating: dataset/train/n01983481_282.JPEG
#   inflating: dataset/train/n01983481_287.JPEG
#   inflating: dataset/train/n01983481_314.JPEG
#   inflating: dataset/train/n01983481_368.JPEG
#   inflating: dataset/train/n01983481_460.JPEG
#   inflating: dataset/train/n01983481_60.JPEG
#   inflating: dataset/train/n01983481_88.JPEG
#   inflating: dataset/train/n01984695_106.JPEG
#   inflating: dataset/train/n01984695_149.JPEG
#   inflating: dataset/train/n01984695_15.JPEG
#   inflating: dataset/train/n01984695_178.JPEG
#   inflating: dataset/train/n01984695_233.JPEG
#   inflating: dataset/train/n01984695_274.JPEG
#   inflating: dataset/train/n01984695_343.JPEG
#   inflating: dataset/train/n01984695_425.JPEG
#   inflating: dataset/train/n01984695_429.JPEG
#   inflating: dataset/train/n01984695_82.JPEG
#   inflating: dataset/train/n02002724_189.JPEG
#   inflating: dataset/train/n02002724_237.JPEG
#   inflating: dataset/train/n02002724_268.JPEG
#   inflating: dataset/train/n02002724_339.JPEG
#   inflating: dataset/train/n02002724_365.JPEG
#   inflating: dataset/train/n02002724_420.JPEG
#   inflating: dataset/train/n02002724_445.JPEG
#   inflating: dataset/train/n02002724_46.JPEG
#   inflating: dataset/train/n02002724_490.JPEG
#   inflating: dataset/train/n02002724_86.JPEG
#   inflating: dataset/train/n02056570_147.JPEG
#   inflating: dataset/train/n02056570_155.JPEG
#   inflating: dataset/train/n02056570_18.JPEG
#   inflating: dataset/train/n02056570_180.JPEG
#   inflating: dataset/train/n02056570_328.JPEG
#   inflating: dataset/train/n02056570_380.JPEG
#   inflating: dataset/train/n02056570_395.JPEG
#   inflating: dataset/train/n02056570_4.JPEG
#   inflating: dataset/train/n02056570_418.JPEG
#   inflating: dataset/train/n02056570_475.JPEG
#   inflating: dataset/train/n02058221_12.JPEG
#   inflating: dataset/train/n02058221_276.JPEG
#   inflating: dataset/train/n02058221_285.JPEG
#   inflating: dataset/train/n02058221_336.JPEG
#   inflating: dataset/train/n02058221_353.JPEG
#   inflating: dataset/train/n02058221_418.JPEG
#   inflating: dataset/train/n02058221_439.JPEG
#   inflating: dataset/train/n02058221_469.JPEG
#   inflating: dataset/train/n02058221_481.JPEG
#   inflating: dataset/train/n02058221_493.JPEG
#   inflating: dataset/train/n02074367_150.JPEG
#   inflating: dataset/train/n02074367_167.JPEG
#   inflating: dataset/train/n02074367_18.JPEG
#   inflating: dataset/train/n02074367_223.JPEG
#   inflating: dataset/train/n02074367_260.JPEG
#   inflating: dataset/train/n02074367_283.JPEG
#   inflating: dataset/train/n02074367_351.JPEG
#   inflating: dataset/train/n02074367_368.JPEG
#   inflating: dataset/train/n02074367_393.JPEG
#   inflating: dataset/train/n02074367_435.JPEG
#   inflating: dataset/train/n02085620_113.JPEG
#   inflating: dataset/train/n02085620_171.JPEG
#   inflating: dataset/train/n02085620_216.JPEG
#   inflating: dataset/train/n02085620_305.JPEG
#   inflating: dataset/train/n02085620_409.JPEG
#   inflating: dataset/train/n02085620_43.JPEG
#   inflating: dataset/train/n02085620_441.JPEG
#   inflating: dataset/train/n02085620_490.JPEG
#   inflating: dataset/train/n02085620_492.JPEG
#   inflating: dataset/train/n02085620_70.JPEG
#   inflating: dataset/train/n02094433_106.JPEG
#   inflating: dataset/train/n02094433_184.JPEG
#   inflating: dataset/train/n02094433_238.JPEG
#   inflating: dataset/train/n02094433_258.JPEG
#   inflating: dataset/train/n02094433_260.JPEG
#   inflating: dataset/train/n02094433_327.JPEG
#   inflating: dataset/train/n02094433_397.JPEG
#   inflating: dataset/train/n02094433_447.JPEG
#   inflating: dataset/train/n02094433_461.JPEG
#   inflating: dataset/train/n02094433_66.JPEG
#   inflating: dataset/train/n02099601_170.JPEG
#   inflating: dataset/train/n02099601_27.JPEG
#   inflating: dataset/train/n02099601_273.JPEG
#   inflating: dataset/train/n02099601_292.JPEG
#   inflating: dataset/train/n02099601_337.JPEG
#   inflating: dataset/train/n02099601_374.JPEG
#   inflating: dataset/train/n02099601_40.JPEG
#   inflating: dataset/train/n02099601_455.JPEG
#   inflating: dataset/train/n02099601_68.JPEG
#   inflating: dataset/train/n02099601_77.JPEG
#   inflating: dataset/train/n02099712_122.JPEG
#   inflating: dataset/train/n02099712_183.JPEG
#   inflating: dataset/train/n02099712_261.JPEG
#   inflating: dataset/train/n02099712_319.JPEG
#   inflating: dataset/train/n02099712_328.JPEG
#   inflating: dataset/train/n02099712_359.JPEG
#   inflating: dataset/train/n02099712_407.JPEG
#   inflating: dataset/train/n02099712_462.JPEG
#   inflating: dataset/train/n02099712_62.JPEG
#   inflating: dataset/train/n02099712_8.JPEG
#   inflating: dataset/train/n02106662_131.JPEG
#   inflating: dataset/train/n02106662_191.JPEG
#   inflating: dataset/train/n02106662_258.JPEG
#   inflating: dataset/train/n02106662_291.JPEG
#   inflating: dataset/train/n02106662_390.JPEG
#   inflating: dataset/train/n02106662_395.JPEG
#   inflating: dataset/train/n02106662_452.JPEG
#   inflating: dataset/train/n02106662_468.JPEG
#   inflating: dataset/train/n02106662_56.JPEG
#   inflating: dataset/train/n02106662_7.JPEG
#   inflating: dataset/train/n02113799_107.JPEG
#   inflating: dataset/train/n02113799_233.JPEG
#   inflating: dataset/train/n02113799_298.JPEG
#   inflating: dataset/train/n02113799_312.JPEG
#   inflating: dataset/train/n02113799_315.JPEG
#   inflating: dataset/train/n02113799_449.JPEG
#   inflating: dataset/train/n02113799_457.JPEG
#   inflating: dataset/train/n02113799_467.JPEG
#   inflating: dataset/train/n02113799_62.JPEG
#   inflating: dataset/train/n02113799_74.JPEG
#   inflating: dataset/train/n02123045_112.JPEG
#   inflating: dataset/train/n02123045_154.JPEG
#   inflating: dataset/train/n02123045_184.JPEG
#   inflating: dataset/train/n02123045_206.JPEG
#   inflating: dataset/train/n02123045_213.JPEG
#   inflating: dataset/train/n02123045_280.JPEG
#   inflating: dataset/train/n02123045_402.JPEG
#   inflating: dataset/train/n02123045_416.JPEG
#   inflating: dataset/train/n02123045_441.JPEG
#   inflating: dataset/train/n02123045_45.JPEG
#   inflating: dataset/train/n02123394_173.JPEG
#   inflating: dataset/train/n02123394_183.JPEG
#   inflating: dataset/train/n02123394_231.JPEG
#   inflating: dataset/train/n02123394_265.JPEG
#   inflating: dataset/train/n02123394_281.JPEG
#   inflating: dataset/train/n02123394_287.JPEG
#   inflating: dataset/train/n02123394_369.JPEG
#   inflating: dataset/train/n02123394_371.JPEG
#   inflating: dataset/train/n02123394_38.JPEG
#   inflating: dataset/train/n02123394_83.JPEG
#   inflating: dataset/train/n02124075_10.JPEG
#   inflating: dataset/train/n02124075_115.JPEG
#   inflating: dataset/train/n02124075_222.JPEG
#   inflating: dataset/train/n02124075_265.JPEG
#   inflating: dataset/train/n02124075_295.JPEG
#   inflating: dataset/train/n02124075_342.JPEG
#   inflating: dataset/train/n02124075_367.JPEG
#   inflating: dataset/train/n02124075_368.JPEG
#   inflating: dataset/train/n02124075_54.JPEG
#   inflating: dataset/train/n02124075_62.JPEG
#   inflating: dataset/train/n02125311_153.JPEG
#   inflating: dataset/train/n02125311_228.JPEG
#   inflating: dataset/train/n02125311_274.JPEG
#   inflating: dataset/train/n02125311_293.JPEG
#   inflating: dataset/train/n02125311_295.JPEG
#   inflating: dataset/train/n02125311_323.JPEG
#   inflating: dataset/train/n02125311_360.JPEG
#   inflating: dataset/train/n02125311_382.JPEG
#   inflating: dataset/train/n02125311_4.JPEG
#   inflating: dataset/train/n02125311_57.JPEG
#   inflating: dataset/train/n02129165_134.JPEG
#   inflating: dataset/train/n02129165_136.JPEG
#   inflating: dataset/train/n02129165_294.JPEG
#   inflating: dataset/train/n02129165_35.JPEG
#   inflating: dataset/train/n02129165_352.JPEG
#   inflating: dataset/train/n02129165_433.JPEG
#   inflating: dataset/train/n02129165_453.JPEG
#   inflating: dataset/train/n02129165_68.JPEG
#   inflating: dataset/train/n02129165_75.JPEG
#   inflating: dataset/train/n02129165_79.JPEG
#   inflating: dataset/train/n02132136_126.JPEG
#   inflating: dataset/train/n02132136_152.JPEG
#   inflating: dataset/train/n02132136_257.JPEG
#   inflating: dataset/train/n02132136_264.JPEG
#   inflating: dataset/train/n02132136_325.JPEG
#   inflating: dataset/train/n02132136_34.JPEG
#   inflating: dataset/train/n02132136_406.JPEG
#   inflating: dataset/train/n02132136_472.JPEG
#   inflating: dataset/train/n02132136_97.JPEG
#   inflating: dataset/train/n02132136_98.JPEG
#   inflating: dataset/train/n02165456_153.JPEG
#   inflating: dataset/train/n02165456_211.JPEG
#   inflating: dataset/train/n02165456_23.JPEG
#   inflating: dataset/train/n02165456_304.JPEG
#   inflating: dataset/train/n02165456_338.JPEG
#   inflating: dataset/train/n02165456_39.JPEG
#   inflating: dataset/train/n02165456_435.JPEG
#   inflating: dataset/train/n02165456_475.JPEG
#   inflating: dataset/train/n02165456_67.JPEG
#   inflating: dataset/train/n02165456_91.JPEG
#   inflating: dataset/train/n02190166_130.JPEG
#   inflating: dataset/train/n02190166_137.JPEG
#   inflating: dataset/train/n02190166_236.JPEG
#   inflating: dataset/train/n02190166_256.JPEG
#   inflating: dataset/train/n02190166_332.JPEG
#   inflating: dataset/train/n02190166_372.JPEG
#   inflating: dataset/train/n02190166_378.JPEG
#   inflating: dataset/train/n02190166_434.JPEG
#   inflating: dataset/train/n02190166_468.JPEG
#   inflating: dataset/train/n02190166_77.JPEG
#   inflating: dataset/train/n02206856_120.JPEG
#   inflating: dataset/train/n02206856_237.JPEG
#   inflating: dataset/train/n02206856_251.JPEG
#   inflating: dataset/train/n02206856_292.JPEG
#   inflating: dataset/train/n02206856_317.JPEG
#   inflating: dataset/train/n02206856_320.JPEG
#   inflating: dataset/train/n02206856_331.JPEG
#   inflating: dataset/train/n02206856_37.JPEG
#   inflating: dataset/train/n02206856_447.JPEG
#   inflating: dataset/train/n02206856_459.JPEG
#   inflating: dataset/train/n02226429_123.JPEG
#   inflating: dataset/train/n02226429_171.JPEG
#   inflating: dataset/train/n02226429_214.JPEG
#   inflating: dataset/train/n02226429_233.JPEG
#   inflating: dataset/train/n02226429_270.JPEG
#   inflating: dataset/train/n02226429_274.JPEG
#   inflating: dataset/train/n02226429_30.JPEG
#   inflating: dataset/train/n02226429_329.JPEG
#   inflating: dataset/train/n02226429_432.JPEG
#   inflating: dataset/train/n02226429_496.JPEG
#   inflating: dataset/train/n02231487_111.JPEG
#   inflating: dataset/train/n02231487_166.JPEG
#   inflating: dataset/train/n02231487_179.JPEG
#   inflating: dataset/train/n02231487_255.JPEG
#   inflating: dataset/train/n02231487_27.JPEG
#   inflating: dataset/train/n02231487_270.JPEG
#   inflating: dataset/train/n02231487_379.JPEG
#   inflating: dataset/train/n02231487_383.JPEG
#   inflating: dataset/train/n02231487_455.JPEG
#   inflating: dataset/train/n02231487_484.JPEG
#   inflating: dataset/train/n02233338_111.JPEG
#   inflating: dataset/train/n02233338_126.JPEG
#   inflating: dataset/train/n02233338_138.JPEG
#   inflating: dataset/train/n02233338_163.JPEG
#   inflating: dataset/train/n02233338_242.JPEG
#   inflating: dataset/train/n02233338_360.JPEG
#   inflating: dataset/train/n02233338_381.JPEG
#   inflating: dataset/train/n02233338_412.JPEG
#   inflating: dataset/train/n02233338_417.JPEG
#   inflating: dataset/train/n02233338_50.JPEG
#   inflating: dataset/train/n02236044_121.JPEG
#   inflating: dataset/train/n02236044_13.JPEG
#   inflating: dataset/train/n02236044_239.JPEG
#   inflating: dataset/train/n02236044_265.JPEG
#   inflating: dataset/train/n02236044_29.JPEG
#   inflating: dataset/train/n02236044_311.JPEG
#   inflating: dataset/train/n02236044_326.JPEG
#   inflating: dataset/train/n02236044_363.JPEG
#   inflating: dataset/train/n02236044_371.JPEG
#   inflating: dataset/train/n02236044_89.JPEG
#   inflating: dataset/train/n02268443_11.JPEG
#   inflating: dataset/train/n02268443_12.JPEG
#   inflating: dataset/train/n02268443_219.JPEG
#   inflating: dataset/train/n02268443_222.JPEG
#   inflating: dataset/train/n02268443_269.JPEG
#   inflating: dataset/train/n02268443_376.JPEG
#   inflating: dataset/train/n02268443_385.JPEG
#   inflating: dataset/train/n02268443_450.JPEG
#   inflating: dataset/train/n02268443_454.JPEG
#   inflating: dataset/train/n02268443_48.JPEG
#   inflating: dataset/train/n02279972_265.JPEG
#   inflating: dataset/train/n02279972_36.JPEG
#   inflating: dataset/train/n02279972_401.JPEG
#   inflating: dataset/train/n02279972_407.JPEG
#   inflating: dataset/train/n02279972_430.JPEG
#   inflating: dataset/train/n02279972_432.JPEG
#   inflating: dataset/train/n02279972_458.JPEG
#   inflating: dataset/train/n02279972_488.JPEG
#   inflating: dataset/train/n02279972_494.JPEG
#   inflating: dataset/train/n02279972_83.JPEG
#   inflating: dataset/train/n02281406_0.JPEG
#   inflating: dataset/train/n02281406_123.JPEG
#   inflating: dataset/train/n02281406_160.JPEG
#   inflating: dataset/train/n02281406_206.JPEG
#   inflating: dataset/train/n02281406_263.JPEG
#   inflating: dataset/train/n02281406_326.JPEG
#   inflating: dataset/train/n02281406_446.JPEG
#   inflating: dataset/train/n02281406_497.JPEG
#   inflating: dataset/train/n02281406_64.JPEG
#   inflating: dataset/train/n02281406_95.JPEG
#   inflating: dataset/train/n02321529_139.JPEG
#   inflating: dataset/train/n02321529_17.JPEG
#   inflating: dataset/train/n02321529_189.JPEG
#   inflating: dataset/train/n02321529_199.JPEG
#   inflating: dataset/train/n02321529_224.JPEG
#   inflating: dataset/train/n02321529_257.JPEG
#   inflating: dataset/train/n02321529_280.JPEG
#   inflating: dataset/train/n02321529_427.JPEG
#   inflating: dataset/train/n02321529_434.JPEG
#   inflating: dataset/train/n02321529_53.JPEG
#   inflating: dataset/train/n02364673_120.JPEG
#   inflating: dataset/train/n02364673_176.JPEG
#   inflating: dataset/train/n02364673_27.JPEG
#   inflating: dataset/train/n02364673_283.JPEG
#   inflating: dataset/train/n02364673_29.JPEG
#   inflating: dataset/train/n02364673_379.JPEG
#   inflating: dataset/train/n02364673_404.JPEG
#   inflating: dataset/train/n02364673_409.JPEG
#   inflating: dataset/train/n02364673_436.JPEG
#   inflating: dataset/train/n02364673_76.JPEG
#   inflating: dataset/train/n02395406_109.JPEG
#   inflating: dataset/train/n02395406_141.JPEG
#   inflating: dataset/train/n02395406_155.JPEG
#   inflating: dataset/train/n02395406_20.JPEG
#   inflating: dataset/train/n02395406_204.JPEG
#   inflating: dataset/train/n02395406_230.JPEG
#   inflating: dataset/train/n02395406_287.JPEG
#   inflating: dataset/train/n02395406_464.JPEG
#   inflating: dataset/train/n02395406_6.JPEG
#   inflating: dataset/train/n02395406_93.JPEG
#   inflating: dataset/train/n02403003_223.JPEG
#   inflating: dataset/train/n02403003_293.JPEG
#   inflating: dataset/train/n02403003_366.JPEG
#   inflating: dataset/train/n02403003_380.JPEG
#   inflating: dataset/train/n02403003_383.JPEG
#   inflating: dataset/train/n02403003_403.JPEG
#   inflating: dataset/train/n02403003_437.JPEG
#   inflating: dataset/train/n02403003_479.JPEG
#   inflating: dataset/train/n02403003_64.JPEG
#   inflating: dataset/train/n02403003_8.JPEG
#   inflating: dataset/train/n02410509_16.JPEG
#   inflating: dataset/train/n02410509_162.JPEG
#   inflating: dataset/train/n02410509_174.JPEG
#   inflating: dataset/train/n02410509_266.JPEG
#   inflating: dataset/train/n02410509_436.JPEG
#  extracting: dataset/train/n02410509_466.JPEG
#   inflating: dataset/train/n02410509_47.JPEG
#   inflating: dataset/train/n02410509_495.JPEG
#   inflating: dataset/train/n02410509_52.JPEG
#   inflating: dataset/train/n02410509_97.JPEG
#   inflating: dataset/train/n02415577_123.JPEG
#   inflating: dataset/train/n02415577_127.JPEG
#   inflating: dataset/train/n02415577_261.JPEG
#   inflating: dataset/train/n02415577_269.JPEG
#   inflating: dataset/train/n02415577_427.JPEG
#   inflating: dataset/train/n02415577_444.JPEG
#   inflating: dataset/train/n02415577_46.JPEG
#   inflating: dataset/train/n02415577_482.JPEG
#   inflating: dataset/train/n02415577_492.JPEG
#   inflating: dataset/train/n02415577_64.JPEG
#   inflating: dataset/train/n02423022_112.JPEG
#   inflating: dataset/train/n02423022_152.JPEG
#   inflating: dataset/train/n02423022_215.JPEG
#   inflating: dataset/train/n02423022_244.JPEG
#   inflating: dataset/train/n02423022_27.JPEG
#   inflating: dataset/train/n02423022_291.JPEG
#   inflating: dataset/train/n02423022_388.JPEG
#   inflating: dataset/train/n02423022_468.JPEG
#   inflating: dataset/train/n02423022_57.JPEG
#   inflating: dataset/train/n02423022_91.JPEG
#   inflating: dataset/train/n02437312_185.JPEG
#   inflating: dataset/train/n02437312_225.JPEG
#   inflating: dataset/train/n02437312_233.JPEG
#   inflating: dataset/train/n02437312_251.JPEG
#   inflating: dataset/train/n02437312_319.JPEG
#   inflating: dataset/train/n02437312_362.JPEG
#   inflating: dataset/train/n02437312_397.JPEG
#   inflating: dataset/train/n02437312_405.JPEG
#   inflating: dataset/train/n02437312_463.JPEG
#   inflating: dataset/train/n02437312_74.JPEG
#   inflating: dataset/train/n02480495_1.JPEG
#   inflating: dataset/train/n02480495_177.JPEG
#   inflating: dataset/train/n02480495_191.JPEG
#   inflating: dataset/train/n02480495_238.JPEG
#   inflating: dataset/train/n02480495_285.JPEG
#   inflating: dataset/train/n02480495_327.JPEG
#  extracting: dataset/train/n02480495_375.JPEG
#   inflating: dataset/train/n02480495_53.JPEG
#   inflating: dataset/train/n02480495_59.JPEG
#   inflating: dataset/train/n02480495_62.JPEG
#   inflating: dataset/train/n02481823_109.JPEG
#   inflating: dataset/train/n02481823_129.JPEG
#   inflating: dataset/train/n02481823_133.JPEG
#   inflating: dataset/train/n02481823_207.JPEG
#   inflating: dataset/train/n02481823_280.JPEG
#   inflating: dataset/train/n02481823_323.JPEG
#   inflating: dataset/train/n02481823_366.JPEG
#   inflating: dataset/train/n02481823_423.JPEG
#   inflating: dataset/train/n02481823_62.JPEG
#   inflating: dataset/train/n02481823_65.JPEG
#   inflating: dataset/train/n02486410_200.JPEG
#   inflating: dataset/train/n02486410_218.JPEG
#   inflating: dataset/train/n02486410_221.JPEG
#   inflating: dataset/train/n02486410_296.JPEG
#   inflating: dataset/train/n02486410_310.JPEG
#   inflating: dataset/train/n02486410_311.JPEG
#   inflating: dataset/train/n02486410_351.JPEG
#   inflating: dataset/train/n02486410_416.JPEG
#   inflating: dataset/train/n02486410_424.JPEG
#   inflating: dataset/train/n02486410_496.JPEG
#   inflating: dataset/train/n02504458_203.JPEG
#   inflating: dataset/train/n02504458_227.JPEG
#   inflating: dataset/train/n02504458_250.JPEG
#   inflating: dataset/train/n02504458_275.JPEG
#   inflating: dataset/train/n02504458_3.JPEG
#   inflating: dataset/train/n02504458_363.JPEG
#   inflating: dataset/train/n02504458_379.JPEG
#   inflating: dataset/train/n02504458_427.JPEG
#   inflating: dataset/train/n02504458_447.JPEG
#   inflating: dataset/train/n02504458_491.JPEG
#   inflating: dataset/train/n02509815_131.JPEG
#   inflating: dataset/train/n02509815_256.JPEG
#   inflating: dataset/train/n02509815_261.JPEG
#   inflating: dataset/train/n02509815_391.JPEG
#   inflating: dataset/train/n02509815_466.JPEG
#   inflating: dataset/train/n02509815_488.JPEG
#   inflating: dataset/train/n02509815_54.JPEG
#   inflating: dataset/train/n02509815_72.JPEG
#   inflating: dataset/train/n02509815_81.JPEG
#   inflating: dataset/train/n02509815_87.JPEG
#   inflating: dataset/train/n02666196_155.JPEG
#   inflating: dataset/train/n02666196_270.JPEG
#   inflating: dataset/train/n02666196_290.JPEG
#   inflating: dataset/train/n02666196_295.JPEG
#   inflating: dataset/train/n02666196_304.JPEG
#   inflating: dataset/train/n02666196_308.JPEG
#   inflating: dataset/train/n02666196_49.JPEG
#   inflating: dataset/train/n02666196_61.JPEG
#   inflating: dataset/train/n02666196_98.JPEG
#   inflating: dataset/train/n02666196_99.JPEG
#   inflating: dataset/train/n02669723_139.JPEG
#   inflating: dataset/train/n02669723_145.JPEG
#   inflating: dataset/train/n02669723_204.JPEG
#   inflating: dataset/train/n02669723_217.JPEG
#   inflating: dataset/train/n02669723_26.JPEG
#   inflating: dataset/train/n02669723_302.JPEG
#   inflating: dataset/train/n02669723_338.JPEG
#   inflating: dataset/train/n02669723_345.JPEG
#   inflating: dataset/train/n02669723_495.JPEG
#   inflating: dataset/train/n02669723_93.JPEG
#   inflating: dataset/train/n02699494_179.JPEG
#   inflating: dataset/train/n02699494_241.JPEG
#   inflating: dataset/train/n02699494_293.JPEG
#   inflating: dataset/train/n02699494_298.JPEG
#   inflating: dataset/train/n02699494_3.JPEG
#   inflating: dataset/train/n02699494_397.JPEG
#   inflating: dataset/train/n02699494_419.JPEG
#   inflating: dataset/train/n02699494_425.JPEG
#   inflating: dataset/train/n02699494_429.JPEG
#   inflating: dataset/train/n02699494_461.JPEG
#   inflating: dataset/train/n02730930_0.JPEG
#   inflating: dataset/train/n02730930_187.JPEG
#   inflating: dataset/train/n02730930_218.JPEG
#   inflating: dataset/train/n02730930_278.JPEG
#   inflating: dataset/train/n02730930_287.JPEG
#   inflating: dataset/train/n02730930_314.JPEG
#   inflating: dataset/train/n02730930_384.JPEG
#   inflating: dataset/train/n02730930_420.JPEG
#   inflating: dataset/train/n02730930_449.JPEG
#   inflating: dataset/train/n02730930_496.JPEG
#   inflating: dataset/train/n02769748_130.JPEG
#   inflating: dataset/train/n02769748_326.JPEG
#   inflating: dataset/train/n02769748_330.JPEG
#   inflating: dataset/train/n02769748_377.JPEG
#   inflating: dataset/train/n02769748_41.JPEG
#   inflating: dataset/train/n02769748_438.JPEG
#   inflating: dataset/train/n02769748_468.JPEG
#   inflating: dataset/train/n02769748_489.JPEG
#   inflating: dataset/train/n02769748_64.JPEG
#   inflating: dataset/train/n02769748_90.JPEG
#   inflating: dataset/train/n02788148_123.JPEG
#   inflating: dataset/train/n02788148_159.JPEG
#   inflating: dataset/train/n02788148_171.JPEG
#   inflating: dataset/train/n02788148_216.JPEG
#   inflating: dataset/train/n02788148_257.JPEG
#   inflating: dataset/train/n02788148_295.JPEG
#   inflating: dataset/train/n02788148_303.JPEG
#   inflating: dataset/train/n02788148_391.JPEG
#   inflating: dataset/train/n02788148_454.JPEG
#   inflating: dataset/train/n02788148_475.JPEG
#   inflating: dataset/train/n02791270_145.JPEG
#   inflating: dataset/train/n02791270_164.JPEG
#   inflating: dataset/train/n02791270_173.JPEG
#   inflating: dataset/train/n02791270_245.JPEG
#   inflating: dataset/train/n02791270_273.JPEG
#   inflating: dataset/train/n02791270_342.JPEG
#   inflating: dataset/train/n02791270_408.JPEG
#   inflating: dataset/train/n02791270_410.JPEG
#   inflating: dataset/train/n02791270_487.JPEG
#   inflating: dataset/train/n02791270_52.JPEG
#   inflating: dataset/train/n02793495_163.JPEG
#   inflating: dataset/train/n02793495_201.JPEG
#   inflating: dataset/train/n02793495_221.JPEG
#   inflating: dataset/train/n02793495_23.JPEG
#   inflating: dataset/train/n02793495_27.JPEG
#   inflating: dataset/train/n02793495_293.JPEG
#   inflating: dataset/train/n02793495_37.JPEG
#   inflating: dataset/train/n02793495_65.JPEG
#   inflating: dataset/train/n02793495_7.JPEG
#   inflating: dataset/train/n02793495_98.JPEG
#   inflating: dataset/train/n02795169_109.JPEG
#  extracting: dataset/train/n02795169_23.JPEG
#   inflating: dataset/train/n02795169_231.JPEG
#   inflating: dataset/train/n02795169_344.JPEG
#   inflating: dataset/train/n02795169_345.JPEG
#   inflating: dataset/train/n02795169_358.JPEG
#   inflating: dataset/train/n02795169_413.JPEG
#   inflating: dataset/train/n02795169_429.JPEG
#   inflating: dataset/train/n02795169_434.JPEG
#   inflating: dataset/train/n02795169_485.JPEG
#   inflating: dataset/train/n02802426_104.JPEG
#   inflating: dataset/train/n02802426_105.JPEG
#   inflating: dataset/train/n02802426_243.JPEG
#   inflating: dataset/train/n02802426_262.JPEG
#   inflating: dataset/train/n02802426_408.JPEG
#   inflating: dataset/train/n02802426_43.JPEG
#   inflating: dataset/train/n02802426_431.JPEG
#   inflating: dataset/train/n02802426_495.JPEG
#   inflating: dataset/train/n02802426_66.JPEG
#   inflating: dataset/train/n02802426_96.JPEG
#   inflating: dataset/train/n02808440_194.JPEG
#   inflating: dataset/train/n02808440_205.JPEG
#   inflating: dataset/train/n02808440_298.JPEG
#   inflating: dataset/train/n02808440_334.JPEG
#   inflating: dataset/train/n02808440_371.JPEG
#   inflating: dataset/train/n02808440_426.JPEG
#   inflating: dataset/train/n02808440_45.JPEG
#   inflating: dataset/train/n02808440_67.JPEG
#   inflating: dataset/train/n02808440_81.JPEG
#   inflating: dataset/train/n02808440_82.JPEG
#  extracting: dataset/train/n02814533_152.JPEG
#   inflating: dataset/train/n02814533_165.JPEG
#   inflating: dataset/train/n02814533_167.JPEG
#   inflating: dataset/train/n02814533_169.JPEG
#   inflating: dataset/train/n02814533_232.JPEG
#   inflating: dataset/train/n02814533_243.JPEG
#   inflating: dataset/train/n02814533_28.JPEG
#   inflating: dataset/train/n02814533_3.JPEG
#   inflating: dataset/train/n02814533_304.JPEG
#   inflating: dataset/train/n02814533_5.JPEG
#   inflating: dataset/train/n02814860_155.JPEG
#   inflating: dataset/train/n02814860_230.JPEG
#   inflating: dataset/train/n02814860_266.JPEG
#   inflating: dataset/train/n02814860_309.JPEG
#   inflating: dataset/train/n02814860_365.JPEG
#   inflating: dataset/train/n02814860_369.JPEG
#   inflating: dataset/train/n02814860_449.JPEG
#   inflating: dataset/train/n02814860_465.JPEG
#   inflating: dataset/train/n02814860_479.JPEG
#   inflating: dataset/train/n02814860_58.JPEG
#   inflating: dataset/train/n02815834_101.JPEG
#   inflating: dataset/train/n02815834_126.JPEG
#   inflating: dataset/train/n02815834_210.JPEG
#   inflating: dataset/train/n02815834_213.JPEG
#   inflating: dataset/train/n02815834_265.JPEG
#   inflating: dataset/train/n02815834_284.JPEG
#   inflating: dataset/train/n02815834_310.JPEG
#   inflating: dataset/train/n02815834_368.JPEG
#   inflating: dataset/train/n02815834_406.JPEG
#   inflating: dataset/train/n02815834_453.JPEG
#   inflating: dataset/train/n02823428_13.JPEG
#   inflating: dataset/train/n02823428_145.JPEG
#   inflating: dataset/train/n02823428_250.JPEG
#   inflating: dataset/train/n02823428_304.JPEG
#   inflating: dataset/train/n02823428_366.JPEG
#   inflating: dataset/train/n02823428_384.JPEG
#   inflating: dataset/train/n02823428_397.JPEG
#  extracting: dataset/train/n02823428_446.JPEG
#   inflating: dataset/train/n02823428_492.JPEG
#   inflating: dataset/train/n02823428_80.JPEG
#   inflating: dataset/train/n02837789_131.JPEG
#  extracting: dataset/train/n02837789_163.JPEG
#   inflating: dataset/train/n02837789_167.JPEG
#   inflating: dataset/train/n02837789_223.JPEG
#   inflating: dataset/train/n02837789_242.JPEG
#   inflating: dataset/train/n02837789_245.JPEG
#   inflating: dataset/train/n02837789_308.JPEG
#   inflating: dataset/train/n02837789_384.JPEG
#   inflating: dataset/train/n02837789_403.JPEG
#   inflating: dataset/train/n02837789_93.JPEG
#   inflating: dataset/train/n02841315_194.JPEG
#   inflating: dataset/train/n02841315_22.JPEG
#   inflating: dataset/train/n02841315_240.JPEG
#  extracting: dataset/train/n02841315_242.JPEG
#   inflating: dataset/train/n02841315_269.JPEG
#   inflating: dataset/train/n02841315_320.JPEG
#   inflating: dataset/train/n02841315_334.JPEG
#   inflating: dataset/train/n02841315_486.JPEG
#   inflating: dataset/train/n02841315_71.JPEG
#   inflating: dataset/train/n02841315_81.JPEG
#   inflating: dataset/train/n02843684_104.JPEG
#   inflating: dataset/train/n02843684_137.JPEG
#   inflating: dataset/train/n02843684_151.JPEG
#   inflating: dataset/train/n02843684_175.JPEG
#   inflating: dataset/train/n02843684_286.JPEG
#   inflating: dataset/train/n02843684_424.JPEG
#   inflating: dataset/train/n02843684_440.JPEG
#   inflating: dataset/train/n02843684_460.JPEG
#   inflating: dataset/train/n02843684_497.JPEG
#   inflating: dataset/train/n02843684_51.JPEG
#   inflating: dataset/train/n02883205_159.JPEG
#   inflating: dataset/train/n02883205_193.JPEG
#   inflating: dataset/train/n02883205_341.JPEG
#   inflating: dataset/train/n02883205_371.JPEG
#   inflating: dataset/train/n02883205_419.JPEG
#   inflating: dataset/train/n02883205_453.JPEG
#   inflating: dataset/train/n02883205_53.JPEG
#   inflating: dataset/train/n02883205_57.JPEG
#   inflating: dataset/train/n02883205_65.JPEG
#   inflating: dataset/train/n02883205_95.JPEG
#   inflating: dataset/train/n02892201_20.JPEG
#   inflating: dataset/train/n02892201_226.JPEG
#   inflating: dataset/train/n02892201_234.JPEG
#   inflating: dataset/train/n02892201_29.JPEG
#   inflating: dataset/train/n02892201_301.JPEG
#   inflating: dataset/train/n02892201_333.JPEG
#  extracting: dataset/train/n02892201_439.JPEG
#   inflating: dataset/train/n02892201_445.JPEG
#   inflating: dataset/train/n02892201_68.JPEG
#   inflating: dataset/train/n02892201_90.JPEG
#   inflating: dataset/train/n02906734_171.JPEG
#   inflating: dataset/train/n02906734_213.JPEG
#   inflating: dataset/train/n02906734_24.JPEG
#   inflating: dataset/train/n02906734_246.JPEG
#   inflating: dataset/train/n02906734_286.JPEG
#   inflating: dataset/train/n02906734_33.JPEG
#   inflating: dataset/train/n02906734_373.JPEG
#   inflating: dataset/train/n02906734_493.JPEG
#   inflating: dataset/train/n02906734_495.JPEG
#   inflating: dataset/train/n02906734_79.JPEG
#  extracting: dataset/train/n02909870_106.JPEG
#   inflating: dataset/train/n02909870_149.JPEG
#   inflating: dataset/train/n02909870_16.JPEG
#   inflating: dataset/train/n02909870_174.JPEG
#   inflating: dataset/train/n02909870_243.JPEG
#   inflating: dataset/train/n02909870_263.JPEG
#   inflating: dataset/train/n02909870_406.JPEG
#   inflating: dataset/train/n02909870_418.JPEG
#   inflating: dataset/train/n02909870_421.JPEG
#   inflating: dataset/train/n02909870_490.JPEG
#   inflating: dataset/train/n02917067_135.JPEG
#   inflating: dataset/train/n02917067_166.JPEG
#   inflating: dataset/train/n02917067_179.JPEG
#   inflating: dataset/train/n02917067_289.JPEG
#   inflating: dataset/train/n02917067_358.JPEG
#   inflating: dataset/train/n02917067_417.JPEG
#   inflating: dataset/train/n02917067_432.JPEG
#   inflating: dataset/train/n02917067_471.JPEG
#   inflating: dataset/train/n02917067_474.JPEG
#   inflating: dataset/train/n02917067_76.JPEG
#   inflating: dataset/train/n02927161_150.JPEG
#   inflating: dataset/train/n02927161_152.JPEG
#   inflating: dataset/train/n02927161_257.JPEG
#   inflating: dataset/train/n02927161_259.JPEG
#   inflating: dataset/train/n02927161_297.JPEG
#   inflating: dataset/train/n02927161_327.JPEG
#   inflating: dataset/train/n02927161_357.JPEG
#   inflating: dataset/train/n02927161_371.JPEG
#   inflating: dataset/train/n02927161_417.JPEG
#   inflating: dataset/train/n02927161_55.JPEG
#   inflating: dataset/train/n02948072_171.JPEG
#   inflating: dataset/train/n02948072_18.JPEG
#   inflating: dataset/train/n02948072_180.JPEG
#   inflating: dataset/train/n02948072_238.JPEG
#   inflating: dataset/train/n02948072_240.JPEG
#   inflating: dataset/train/n02948072_265.JPEG
#   inflating: dataset/train/n02948072_303.JPEG
#   inflating: dataset/train/n02948072_361.JPEG
#   inflating: dataset/train/n02948072_60.JPEG
#   inflating: dataset/train/n02948072_79.JPEG
#   inflating: dataset/train/n02950826_12.JPEG
#   inflating: dataset/train/n02950826_170.JPEG
#   inflating: dataset/train/n02950826_173.JPEG
#   inflating: dataset/train/n02950826_19.JPEG
#   inflating: dataset/train/n02950826_231.JPEG
#  extracting: dataset/train/n02950826_259.JPEG
#   inflating: dataset/train/n02950826_325.JPEG
#   inflating: dataset/train/n02950826_328.JPEG
#   inflating: dataset/train/n02950826_437.JPEG
#   inflating: dataset/train/n02950826_466.JPEG
#   inflating: dataset/train/n02963159_149.JPEG
#   inflating: dataset/train/n02963159_232.JPEG
#   inflating: dataset/train/n02963159_256.JPEG
#   inflating: dataset/train/n02963159_333.JPEG
#   inflating: dataset/train/n02963159_406.JPEG
#   inflating: dataset/train/n02963159_410.JPEG
#   inflating: dataset/train/n02963159_424.JPEG
#   inflating: dataset/train/n02963159_50.JPEG
#   inflating: dataset/train/n02963159_60.JPEG
#   inflating: dataset/train/n02963159_76.JPEG
#   inflating: dataset/train/n02977058_121.JPEG
#   inflating: dataset/train/n02977058_160.JPEG
#   inflating: dataset/train/n02977058_174.JPEG
#   inflating: dataset/train/n02977058_203.JPEG
#   inflating: dataset/train/n02977058_204.JPEG
#   inflating: dataset/train/n02977058_387.JPEG
#   inflating: dataset/train/n02977058_4.JPEG
#   inflating: dataset/train/n02977058_412.JPEG
#   inflating: dataset/train/n02977058_481.JPEG
#   inflating: dataset/train/n02977058_98.JPEG
#   inflating: dataset/train/n02988304_119.JPEG
#   inflating: dataset/train/n02988304_14.JPEG
#   inflating: dataset/train/n02988304_180.JPEG
#   inflating: dataset/train/n02988304_276.JPEG
#   inflating: dataset/train/n02988304_336.JPEG
#   inflating: dataset/train/n02988304_352.JPEG
#   inflating: dataset/train/n02988304_366.JPEG
#   inflating: dataset/train/n02988304_453.JPEG
#   inflating: dataset/train/n02988304_487.JPEG
#   inflating: dataset/train/n02988304_70.JPEG
#   inflating: dataset/train/n02999410_184.JPEG
#   inflating: dataset/train/n02999410_195.JPEG
#   inflating: dataset/train/n02999410_283.JPEG
#   inflating: dataset/train/n02999410_284.JPEG
#   inflating: dataset/train/n02999410_317.JPEG
#   inflating: dataset/train/n02999410_324.JPEG
#   inflating: dataset/train/n02999410_347.JPEG
#   inflating: dataset/train/n02999410_355.JPEG
#   inflating: dataset/train/n02999410_433.JPEG
#   inflating: dataset/train/n02999410_45.JPEG
#   inflating: dataset/train/n03014705_113.JPEG
#   inflating: dataset/train/n03014705_115.JPEG
#   inflating: dataset/train/n03014705_173.JPEG
#   inflating: dataset/train/n03014705_250.JPEG
#   inflating: dataset/train/n03014705_284.JPEG
#   inflating: dataset/train/n03014705_356.JPEG
#   inflating: dataset/train/n03014705_403.JPEG
#   inflating: dataset/train/n03014705_459.JPEG
#   inflating: dataset/train/n03014705_47.JPEG
#   inflating: dataset/train/n03014705_479.JPEG
#   inflating: dataset/train/n03026506_104.JPEG
#   inflating: dataset/train/n03026506_190.JPEG
#   inflating: dataset/train/n03026506_233.JPEG
#   inflating: dataset/train/n03026506_289.JPEG
#   inflating: dataset/train/n03026506_309.JPEG
#   inflating: dataset/train/n03026506_316.JPEG
#   inflating: dataset/train/n03026506_371.JPEG
#   inflating: dataset/train/n03026506_419.JPEG
#   inflating: dataset/train/n03026506_433.JPEG
#   inflating: dataset/train/n03026506_97.JPEG
#   inflating: dataset/train/n03042490_12.JPEG
#   inflating: dataset/train/n03042490_173.JPEG
#   inflating: dataset/train/n03042490_29.JPEG
#   inflating: dataset/train/n03042490_334.JPEG
#   inflating: dataset/train/n03042490_396.JPEG
#   inflating: dataset/train/n03042490_4.JPEG
#   inflating: dataset/train/n03042490_406.JPEG
#   inflating: dataset/train/n03042490_424.JPEG
#   inflating: dataset/train/n03042490_71.JPEG
#   inflating: dataset/train/n03042490_95.JPEG
#   inflating: dataset/train/n03085013_189.JPEG
#   inflating: dataset/train/n03085013_312.JPEG
#   inflating: dataset/train/n03085013_364.JPEG
#   inflating: dataset/train/n03085013_435.JPEG
#   inflating: dataset/train/n03085013_463.JPEG
#   inflating: dataset/train/n03085013_495.JPEG
#   inflating: dataset/train/n03085013_57.JPEG
#   inflating: dataset/train/n03085013_60.JPEG
#   inflating: dataset/train/n03085013_64.JPEG
#   inflating: dataset/train/n03085013_9.JPEG
#   inflating: dataset/train/n03089624_106.JPEG
#   inflating: dataset/train/n03089624_116.JPEG
#   inflating: dataset/train/n03089624_197.JPEG
#   inflating: dataset/train/n03089624_211.JPEG
#   inflating: dataset/train/n03089624_249.JPEG
#   inflating: dataset/train/n03089624_373.JPEG
#   inflating: dataset/train/n03089624_412.JPEG
#   inflating: dataset/train/n03089624_446.JPEG
#   inflating: dataset/train/n03089624_447.JPEG
#   inflating: dataset/train/n03089624_67.JPEG
#   inflating: dataset/train/n03100240_133.JPEG
#   inflating: dataset/train/n03100240_159.JPEG
#   inflating: dataset/train/n03100240_172.JPEG
#   inflating: dataset/train/n03100240_174.JPEG
#   inflating: dataset/train/n03100240_24.JPEG
#   inflating: dataset/train/n03100240_241.JPEG
#   inflating: dataset/train/n03100240_297.JPEG
#   inflating: dataset/train/n03100240_331.JPEG
#   inflating: dataset/train/n03100240_397.JPEG
#   inflating: dataset/train/n03100240_40.JPEG
#   inflating: dataset/train/n03126707_119.JPEG
#   inflating: dataset/train/n03126707_162.JPEG
#   inflating: dataset/train/n03126707_282.JPEG
#   inflating: dataset/train/n03126707_300.JPEG
#   inflating: dataset/train/n03126707_303.JPEG
#   inflating: dataset/train/n03126707_327.JPEG
#   inflating: dataset/train/n03126707_356.JPEG
#   inflating: dataset/train/n03126707_470.JPEG
#   inflating: dataset/train/n03126707_87.JPEG
#   inflating: dataset/train/n03126707_97.JPEG
#   inflating: dataset/train/n03160309_10.JPEG
#   inflating: dataset/train/n03160309_112.JPEG
#   inflating: dataset/train/n03160309_173.JPEG
#   inflating: dataset/train/n03160309_180.JPEG
#   inflating: dataset/train/n03160309_252.JPEG
#   inflating: dataset/train/n03160309_327.JPEG
#   inflating: dataset/train/n03160309_357.JPEG
#   inflating: dataset/train/n03160309_391.JPEG
#   inflating: dataset/train/n03160309_427.JPEG
#   inflating: dataset/train/n03160309_8.JPEG
#   inflating: dataset/train/n03179701_18.JPEG
#   inflating: dataset/train/n03179701_227.JPEG
#   inflating: dataset/train/n03179701_30.JPEG
#   inflating: dataset/train/n03179701_393.JPEG
#   inflating: dataset/train/n03179701_415.JPEG
#   inflating: dataset/train/n03179701_422.JPEG
#   inflating: dataset/train/n03179701_458.JPEG
#   inflating: dataset/train/n03179701_68.JPEG
#   inflating: dataset/train/n03179701_7.JPEG
#   inflating: dataset/train/n03179701_88.JPEG
#   inflating: dataset/train/n03201208_13.JPEG
#   inflating: dataset/train/n03201208_191.JPEG
#   inflating: dataset/train/n03201208_270.JPEG
#   inflating: dataset/train/n03201208_302.JPEG
#   inflating: dataset/train/n03201208_309.JPEG
#   inflating: dataset/train/n03201208_312.JPEG
#   inflating: dataset/train/n03201208_366.JPEG
#   inflating: dataset/train/n03201208_388.JPEG
#   inflating: dataset/train/n03201208_439.JPEG
#   inflating: dataset/train/n03201208_98.JPEG
#   inflating: dataset/train/n03250847_123.JPEG
#   inflating: dataset/train/n03250847_209.JPEG
#   inflating: dataset/train/n03250847_250.JPEG
#   inflating: dataset/train/n03250847_261.JPEG
#   inflating: dataset/train/n03250847_329.JPEG
#   inflating: dataset/train/n03250847_391.JPEG
#   inflating: dataset/train/n03250847_476.JPEG
#   inflating: dataset/train/n03250847_485.JPEG
#   inflating: dataset/train/n03250847_59.JPEG
#   inflating: dataset/train/n03250847_60.JPEG
#   inflating: dataset/train/n03255030_162.JPEG
#   inflating: dataset/train/n03255030_164.JPEG
#   inflating: dataset/train/n03255030_279.JPEG
# ...
#   inflating: dataset/valid/n03670208_61.JPEG
#   inflating: dataset/valid/n03706229_173.JPEG
#   inflating: dataset/valid/n03706229_184.JPEG
#   inflating: dataset/valid/n03706229_302.JPEG
#   inflating: dataset/valid/n03706229_473.JPEG
#   inflating: dataset/valid/n03733131_252.JPEG
#   inflating: dataset/valid/n03733131_383.JPEG
#   inflating: dataset/valid/n03733131_46.JPEG
#   inflating: dataset/valid/n03733131_86.JPEG
#   inflating: dataset/valid/n03763968_208.JPEG
#   inflating: dataset/valid/n03763968_222.JPEG
#   inflating: dataset/valid/n03763968_226.JPEG
#   inflating: dataset/valid/n03763968_307.JPEG
#   inflating: dataset/valid/n03770439_454.JPEG
#   inflating: dataset/valid/n03770439_66.JPEG
#   inflating: dataset/valid/n03770439_7.JPEG
#   inflating: dataset/valid/n03770439_89.JPEG
#   inflating: dataset/valid/n03796401_230.JPEG
#   inflating: dataset/valid/n03796401_270.JPEG
#   inflating: dataset/valid/n03796401_435.JPEG
#   inflating: dataset/valid/n03796401_495.JPEG
#   inflating: dataset/valid/n03804744_251.JPEG
#   inflating: dataset/valid/n03804744_268.JPEG
#   inflating: dataset/valid/n03804744_27.JPEG
#   inflating: dataset/valid/n03804744_59.JPEG
#   inflating: dataset/valid/n03814639_160.JPEG
#   inflating: dataset/valid/n03814639_177.JPEG
#   inflating: dataset/valid/n03814639_248.JPEG
#   inflating: dataset/valid/n03814639_272.JPEG
#   inflating: dataset/valid/n03837869_13.JPEG
#   inflating: dataset/valid/n03837869_311.JPEG
#   inflating: dataset/valid/n03837869_363.JPEG
#   inflating: dataset/valid/n03837869_8.JPEG
#   inflating: dataset/valid/n03838899_105.JPEG
#   inflating: dataset/valid/n03838899_173.JPEG
#   inflating: dataset/valid/n03838899_308.JPEG
#   inflating: dataset/valid/n03838899_76.JPEG
#   inflating: dataset/valid/n03854065_138.JPEG
#   inflating: dataset/valid/n03854065_216.JPEG
#   inflating: dataset/valid/n03854065_226.JPEG
#   inflating: dataset/valid/n03854065_73.JPEG
#   inflating: dataset/valid/n03891332_317.JPEG
#   inflating: dataset/valid/n03891332_322.JPEG
#   inflating: dataset/valid/n03891332_325.JPEG
#   inflating: dataset/valid/n03891332_471.JPEG
#   inflating: dataset/valid/n03902125_120.JPEG
#   inflating: dataset/valid/n03902125_253.JPEG
#   inflating: dataset/valid/n03902125_277.JPEG
#   inflating: dataset/valid/n03902125_296.JPEG
#   inflating: dataset/valid/n03930313_104.JPEG
#   inflating: dataset/valid/n03930313_154.JPEG
#   inflating: dataset/valid/n03930313_248.JPEG
#   inflating: dataset/valid/n03930313_6.JPEG
#   inflating: dataset/valid/n03937543_126.JPEG
#   inflating: dataset/valid/n03937543_140.JPEG
#   inflating: dataset/valid/n03937543_217.JPEG
#   inflating: dataset/valid/n03937543_388.JPEG
#   inflating: dataset/valid/n03970156_144.JPEG
#   inflating: dataset/valid/n03970156_152.JPEG
#   inflating: dataset/valid/n03970156_234.JPEG
#   inflating: dataset/valid/n03970156_284.JPEG
#   inflating: dataset/valid/n03976657_217.JPEG
#   inflating: dataset/valid/n03976657_25.JPEG
#   inflating: dataset/valid/n03976657_311.JPEG
#   inflating: dataset/valid/n03976657_414.JPEG
#   inflating: dataset/valid/n03977966_202.JPEG
#   inflating: dataset/valid/n03977966_301.JPEG
#   inflating: dataset/valid/n03977966_401.JPEG
#   inflating: dataset/valid/n03977966_482.JPEG
#   inflating: dataset/valid/n03980874_221.JPEG
#   inflating: dataset/valid/n03980874_383.JPEG
#   inflating: dataset/valid/n03980874_39.JPEG
#   inflating: dataset/valid/n03980874_391.JPEG
#   inflating: dataset/valid/n03983396_220.JPEG
#   inflating: dataset/valid/n03983396_228.JPEG
#   inflating: dataset/valid/n03983396_297.JPEG
#   inflating: dataset/valid/n03983396_45.JPEG
#   inflating: dataset/valid/n03992509_26.JPEG
#   inflating: dataset/valid/n03992509_276.JPEG
#   inflating: dataset/valid/n03992509_315.JPEG
#   inflating: dataset/valid/n03992509_481.JPEG
#   inflating: dataset/valid/n04008634_117.JPEG
#   inflating: dataset/valid/n04008634_252.JPEG
#   inflating: dataset/valid/n04008634_353.JPEG
#   inflating: dataset/valid/n04008634_65.JPEG
#   inflating: dataset/valid/n04023962_211.JPEG
#  extracting: dataset/valid/n04023962_251.JPEG
#   inflating: dataset/valid/n04023962_30.JPEG
#   inflating: dataset/valid/n04023962_347.JPEG
#   inflating: dataset/valid/n04067472_13.JPEG
#   inflating: dataset/valid/n04067472_154.JPEG
#   inflating: dataset/valid/n04067472_195.JPEG
#   inflating: dataset/valid/n04067472_26.JPEG
#   inflating: dataset/valid/n04070727_215.JPEG
#   inflating: dataset/valid/n04070727_257.JPEG
#   inflating: dataset/valid/n04070727_440.JPEG
#   inflating: dataset/valid/n04070727_489.JPEG
#   inflating: dataset/valid/n04074963_221.JPEG
#   inflating: dataset/valid/n04074963_234.JPEG
#   inflating: dataset/valid/n04074963_251.JPEG
#   inflating: dataset/valid/n04074963_321.JPEG
#   inflating: dataset/valid/n04099969_193.JPEG
#   inflating: dataset/valid/n04099969_2.JPEG
#   inflating: dataset/valid/n04099969_496.JPEG
#   inflating: dataset/valid/n04099969_6.JPEG
#   inflating: dataset/valid/n04118538_297.JPEG
#   inflating: dataset/valid/n04118538_457.JPEG
#   inflating: dataset/valid/n04118538_481.JPEG
#   inflating: dataset/valid/n04118538_72.JPEG
#   inflating: dataset/valid/n04133789_12.JPEG
#   inflating: dataset/valid/n04133789_21.JPEG
#   inflating: dataset/valid/n04133789_260.JPEG
#   inflating: dataset/valid/n04133789_496.JPEG
#   inflating: dataset/valid/n04146614_184.JPEG
#   inflating: dataset/valid/n04146614_276.JPEG
#   inflating: dataset/valid/n04146614_426.JPEG
#   inflating: dataset/valid/n04146614_431.JPEG
#   inflating: dataset/valid/n04149813_283.JPEG
#   inflating: dataset/valid/n04149813_343.JPEG
#   inflating: dataset/valid/n04149813_376.JPEG
#   inflating: dataset/valid/n04149813_483.JPEG
#   inflating: dataset/valid/n04179913_254.JPEG
#   inflating: dataset/valid/n04179913_358.JPEG
#   inflating: dataset/valid/n04179913_399.JPEG
#   inflating: dataset/valid/n04179913_45.JPEG
#   inflating: dataset/valid/n04251144_105.JPEG
#   inflating: dataset/valid/n04251144_13.JPEG
#   inflating: dataset/valid/n04251144_38.JPEG
#   inflating: dataset/valid/n04251144_88.JPEG
#   inflating: dataset/valid/n04254777_174.JPEG
#   inflating: dataset/valid/n04254777_184.JPEG
#   inflating: dataset/valid/n04254777_294.JPEG
#   inflating: dataset/valid/n04254777_332.JPEG
#   inflating: dataset/valid/n04259630_108.JPEG
#   inflating: dataset/valid/n04259630_132.JPEG
#   inflating: dataset/valid/n04259630_274.JPEG
#   inflating: dataset/valid/n04259630_350.JPEG
#   inflating: dataset/valid/n04265275_277.JPEG
#   inflating: dataset/valid/n04265275_349.JPEG
#   inflating: dataset/valid/n04265275_35.JPEG
#   inflating: dataset/valid/n04265275_61.JPEG
#   inflating: dataset/valid/n04275548_125.JPEG
#   inflating: dataset/valid/n04275548_155.JPEG
#   inflating: dataset/valid/n04275548_235.JPEG
#   inflating: dataset/valid/n04275548_499.JPEG
#   inflating: dataset/valid/n04285008_196.JPEG
#   inflating: dataset/valid/n04285008_390.JPEG
#   inflating: dataset/valid/n04285008_400.JPEG
#   inflating: dataset/valid/n04285008_485.JPEG
#   inflating: dataset/valid/n04311004_121.JPEG
#   inflating: dataset/valid/n04311004_158.JPEG
#   inflating: dataset/valid/n04311004_270.JPEG
#   inflating: dataset/valid/n04311004_320.JPEG
#   inflating: dataset/valid/n04328186_115.JPEG
#  extracting: dataset/valid/n04328186_293.JPEG
#   inflating: dataset/valid/n04328186_36.JPEG
#   inflating: dataset/valid/n04328186_468.JPEG
#  extracting: dataset/valid/n04356056_101.JPEG
#   inflating: dataset/valid/n04356056_103.JPEG
#   inflating: dataset/valid/n04356056_266.JPEG
#   inflating: dataset/valid/n04356056_370.JPEG
#   inflating: dataset/valid/n04366367_190.JPEG
#   inflating: dataset/valid/n04366367_340.JPEG
#  extracting: dataset/valid/n04366367_439.JPEG
#   inflating: dataset/valid/n04366367_98.JPEG
#   inflating: dataset/valid/n04371430_154.JPEG
#   inflating: dataset/valid/n04371430_319.JPEG
#   inflating: dataset/valid/n04371430_337.JPEG
#   inflating: dataset/valid/n04371430_429.JPEG
#   inflating: dataset/valid/n04376876_125.JPEG
#   inflating: dataset/valid/n04376876_135.JPEG
#   inflating: dataset/valid/n04376876_256.JPEG
#   inflating: dataset/valid/n04376876_472.JPEG
#   inflating: dataset/valid/n04398044_1.JPEG
#   inflating: dataset/valid/n04398044_281.JPEG
#   inflating: dataset/valid/n04398044_68.JPEG
#   inflating: dataset/valid/n04398044_84.JPEG
#   inflating: dataset/valid/n04399382_122.JPEG
#   inflating: dataset/valid/n04399382_322.JPEG
#   inflating: dataset/valid/n04399382_365.JPEG
#   inflating: dataset/valid/n04399382_384.JPEG
#   inflating: dataset/valid/n04417672_122.JPEG
#   inflating: dataset/valid/n04417672_297.JPEG
#   inflating: dataset/valid/n04417672_308.JPEG
#   inflating: dataset/valid/n04417672_415.JPEG
#   inflating: dataset/valid/n04456115_146.JPEG
#   inflating: dataset/valid/n04456115_264.JPEG
#   inflating: dataset/valid/n04456115_4.JPEG
#   inflating: dataset/valid/n04456115_402.JPEG
#   inflating: dataset/valid/n04465501_118.JPEG
#   inflating: dataset/valid/n04465501_134.JPEG
#   inflating: dataset/valid/n04465501_233.JPEG
#   inflating: dataset/valid/n04465501_25.JPEG
#   inflating: dataset/valid/n04486054_266.JPEG
#   inflating: dataset/valid/n04486054_340.JPEG
#   inflating: dataset/valid/n04486054_376.JPEG
#   inflating: dataset/valid/n04486054_443.JPEG
#   inflating: dataset/valid/n04487081_133.JPEG
#   inflating: dataset/valid/n04487081_422.JPEG
#   inflating: dataset/valid/n04487081_43.JPEG
#   inflating: dataset/valid/n04487081_436.JPEG
#   inflating: dataset/valid/n04501370_202.JPEG
#   inflating: dataset/valid/n04501370_461.JPEG
#   inflating: dataset/valid/n04501370_489.JPEG
#   inflating: dataset/valid/n04501370_70.JPEG
#   inflating: dataset/valid/n04507155_117.JPEG
#   inflating: dataset/valid/n04507155_133.JPEG
#   inflating: dataset/valid/n04507155_288.JPEG
#   inflating: dataset/valid/n04507155_355.JPEG
#   inflating: dataset/valid/n04532106_111.JPEG
#   inflating: dataset/valid/n04532106_214.JPEG
#   inflating: dataset/valid/n04532106_352.JPEG
#   inflating: dataset/valid/n04532106_468.JPEG
#   inflating: dataset/valid/n04532670_25.JPEG
#  extracting: dataset/valid/n04532670_290.JPEG
#   inflating: dataset/valid/n04532670_417.JPEG
#   inflating: dataset/valid/n04532670_80.JPEG
#   inflating: dataset/valid/n04540053_128.JPEG
#   inflating: dataset/valid/n04540053_198.JPEG
#   inflating: dataset/valid/n04540053_386.JPEG
#   inflating: dataset/valid/n04540053_431.JPEG
#   inflating: dataset/valid/n04560804_111.JPEG
#   inflating: dataset/valid/n04560804_311.JPEG
#   inflating: dataset/valid/n04560804_4.JPEG
#   inflating: dataset/valid/n04560804_436.JPEG
#   inflating: dataset/valid/n04562935_17.JPEG
#  extracting: dataset/valid/n04562935_264.JPEG
#   inflating: dataset/valid/n04562935_439.JPEG
#   inflating: dataset/valid/n04562935_76.JPEG
#   inflating: dataset/valid/n04596742_214.JPEG
#   inflating: dataset/valid/n04596742_380.JPEG
#   inflating: dataset/valid/n04596742_436.JPEG
#   inflating: dataset/valid/n04596742_497.JPEG
#   inflating: dataset/valid/n04597913_13.JPEG
#   inflating: dataset/valid/n04597913_255.JPEG
#   inflating: dataset/valid/n04597913_330.JPEG
#   inflating: dataset/valid/n04597913_379.JPEG
#   inflating: dataset/valid/n06596364_140.JPEG
#   inflating: dataset/valid/n06596364_200.JPEG
#   inflating: dataset/valid/n06596364_278.JPEG
#   inflating: dataset/valid/n06596364_412.JPEG
#   inflating: dataset/valid/n07579787_307.JPEG
#   inflating: dataset/valid/n07579787_464.JPEG
#   inflating: dataset/valid/n07579787_64.JPEG
#   inflating: dataset/valid/n07579787_99.JPEG
#   inflating: dataset/valid/n07583066_14.JPEG
#   inflating: dataset/valid/n07583066_184.JPEG
#   inflating: dataset/valid/n07583066_271.JPEG
#   inflating: dataset/valid/n07583066_440.JPEG
#   inflating: dataset/valid/n07614500_207.JPEG
#   inflating: dataset/valid/n07614500_43.JPEG
#   inflating: dataset/valid/n07614500_450.JPEG
#   inflating: dataset/valid/n07614500_65.JPEG
#   inflating: dataset/valid/n07615774_270.JPEG
#   inflating: dataset/valid/n07615774_275.JPEG
#   inflating: dataset/valid/n07615774_440.JPEG
#   inflating: dataset/valid/n07615774_444.JPEG
#   inflating: dataset/valid/n07695742_132.JPEG
#   inflating: dataset/valid/n07695742_180.JPEG
#   inflating: dataset/valid/n07695742_339.JPEG
#   inflating: dataset/valid/n07695742_77.JPEG
#   inflating: dataset/valid/n07711569_135.JPEG
#   inflating: dataset/valid/n07711569_337.JPEG
#   inflating: dataset/valid/n07711569_411.JPEG
#   inflating: dataset/valid/n07711569_435.JPEG
#   inflating: dataset/valid/n07715103_139.JPEG
#   inflating: dataset/valid/n07715103_155.JPEG
#  extracting: dataset/valid/n07715103_398.JPEG
#   inflating: dataset/valid/n07715103_89.JPEG
#   inflating: dataset/valid/n07720875_215.JPEG
#   inflating: dataset/valid/n07720875_320.JPEG
#   inflating: dataset/valid/n07720875_53.JPEG
#   inflating: dataset/valid/n07720875_96.JPEG
#   inflating: dataset/valid/n07734744_146.JPEG
#   inflating: dataset/valid/n07734744_355.JPEG
#   inflating: dataset/valid/n07734744_55.JPEG
#   inflating: dataset/valid/n07734744_9.JPEG
#   inflating: dataset/valid/n07747607_114.JPEG
#   inflating: dataset/valid/n07747607_120.JPEG
#   inflating: dataset/valid/n07747607_222.JPEG
#   inflating: dataset/valid/n07747607_335.JPEG
#   inflating: dataset/valid/n07749582_121.JPEG
#   inflating: dataset/valid/n07749582_369.JPEG
#   inflating: dataset/valid/n07749582_374.JPEG
#   inflating: dataset/valid/n07749582_44.JPEG
#   inflating: dataset/valid/n07753592_123.JPEG
#   inflating: dataset/valid/n07753592_14.JPEG
#   inflating: dataset/valid/n07753592_31.JPEG
#   inflating: dataset/valid/n07753592_338.JPEG
#   inflating: dataset/valid/n07768694_149.JPEG
#   inflating: dataset/valid/n07768694_171.JPEG
#   inflating: dataset/valid/n07768694_202.JPEG
#   inflating: dataset/valid/n07768694_232.JPEG
#   inflating: dataset/valid/n07871810_488.JPEG
#   inflating: dataset/valid/n07871810_58.JPEG
#   inflating: dataset/valid/n07871810_80.JPEG
#   inflating: dataset/valid/n07871810_82.JPEG
#   inflating: dataset/valid/n07873807_101.JPEG
#   inflating: dataset/valid/n07873807_189.JPEG
#   inflating: dataset/valid/n07873807_499.JPEG
#   inflating: dataset/valid/n07873807_88.JPEG
#   inflating: dataset/valid/n07875152_114.JPEG
#   inflating: dataset/valid/n07875152_352.JPEG
#   inflating: dataset/valid/n07875152_434.JPEG
#   inflating: dataset/valid/n07875152_438.JPEG
#   inflating: dataset/valid/n07920052_115.JPEG
#   inflating: dataset/valid/n07920052_155.JPEG
#   inflating: dataset/valid/n07920052_482.JPEG
#   inflating: dataset/valid/n07920052_489.JPEG
#   inflating: dataset/valid/n09193705_270.JPEG
#   inflating: dataset/valid/n09193705_291.JPEG
#   inflating: dataset/valid/n09193705_38.JPEG
#   inflating: dataset/valid/n09193705_481.JPEG
#   inflating: dataset/valid/n09246464_130.JPEG
#   inflating: dataset/valid/n09246464_154.JPEG
#   inflating: dataset/valid/n09246464_354.JPEG
#   inflating: dataset/valid/n09246464_439.JPEG
#   inflating: dataset/valid/n09256479_100.JPEG
#   inflating: dataset/valid/n09256479_141.JPEG
#   inflating: dataset/valid/n09256479_266.JPEG
#   inflating: dataset/valid/n09256479_378.JPEG
#   inflating: dataset/valid/n09332890_117.JPEG
#   inflating: dataset/valid/n09332890_358.JPEG
#   inflating: dataset/valid/n09332890_367.JPEG
#   inflating: dataset/valid/n09332890_398.JPEG
#   inflating: dataset/valid/n09428293_232.JPEG
#   inflating: dataset/valid/n09428293_332.JPEG
#   inflating: dataset/valid/n09428293_379.JPEG
#   inflating: dataset/valid/n09428293_475.JPEG
#   inflating: dataset/valid/n12267677_140.JPEG
#   inflating: dataset/valid/n12267677_186.JPEG
#   inflating: dataset/valid/n12267677_343.JPEG
#   inflating: dataset/valid/n12267677_463.JPEG
#   inflating: dataset/validation_dataset.csv

# %%
IMG_SIZE = 64
LEARNING_RATE  = 0.001
COVER_LOSS_WEIGHT = 1
SECRET_LOSS_WEIGHT = 1
TRAIN_BATCH_SIZE = 16
VALID_BATCH_SIZE = 1
EPOCHS = 1000
DECODER_LOSS_WEIGHT = 1

# %%
transformations = {
    'train_transforms':torchvision.transforms.Compose([torchvision.transforms.Resize((IMG_SIZE,IMG_SIZE)),torchvision.transforms.ToTensor()]),
    'valid_transforms':torchvision.transforms.Compose([torchvision.transforms.Resize((IMG_SIZE,IMG_SIZE)),torchvision.transforms.ToTensor()])
}

class SteganoDataset(torch.utils.data.Dataset):
    def __init__(self,dataset_csv,transforms,type_of_dataset,size='complete'):
        self.dataset = pd.read_csv(dataset_csv)
        self.dataset = self.dataset.reset_index(drop=True)
        if size !='complete':
            self.dataset = self.dataset[:4]
        self.transforms = transforms
        self.type = type_of_dataset

    def __getitem__(self,index):
        cover_image = self.dataset.iloc[index]['cover_image']
        secret_image1 = self.dataset.iloc[index]['secret_image_1']
        secret_image2 = self.dataset.iloc[index]['secret_image_2']
        secret_image3 = self.dataset.iloc[index]['secret_image_3']

        cover_image = Image.open(os.path.join(dataset_path,self.type,cover_image))
        secret_image1 = Image.open(os.path.join(dataset_path,self.type,secret_image1))
        secret_image2 = Image.open(os.path.join(dataset_path,self.type,secret_image2))
        secret_image3 = Image.open(os.path.join(dataset_path,self.type,secret_image3))

        transformed_cover_image = self.transforms(cover_image)
        transformed_secret_image_1 = self.transforms(secret_image1)
        transformed_secret_image_2 = self.transforms(secret_image2)
        transformed_secret_image_3 = self.transforms(secret_image3)

        if self.type == 'train':
            return {
                'cover_image':transformed_cover_image,
                'secret_image_1':transformed_secret_image_1,
                'secret_image_2':transformed_secret_image_2,
                'secret_image_3':transformed_secret_image_3
            }
        else:
            return {
                'cover_image':transformed_cover_image,
                'secret_image_1':transformed_secret_image_1,
                'secret_image_2':transformed_secret_image_2,
                'secret_image_3':transformed_secret_image_3
            }

    def __len__(self):
        return len(self.dataset)

# %%
class PrepNetwork1(nn.Module):
    def __init__(self):
        super(PrepNetwork1, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv2 = nn.Conv2d(in_channels=3,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv3 = nn.Conv2d(in_channels=3,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv4 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv5 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv6 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

    def forward(self,secret_image):
        output_1 = F.relu(self.conv1(secret_image))
        output_2 = F.relu(self.conv2(secret_image))
        output_3 = F.relu(self.conv3(secret_image))

        concatenated_image = torch.cat([output_1,output_2,output_3],dim=1)
        output_4 = F.relu(self.conv4(concatenated_image))
        output_5 = F.relu(self.conv5(concatenated_image))
        output_6 = F.relu(self.conv6(concatenated_image))

        final_concat_image = torch.cat([output_4,output_5,output_6],dim=1)
        return final_concat_image

class PrepNetwork2(nn.Module):
    def __init__(self):
        super(PrepNetwork2, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv2 = nn.Conv2d(in_channels=3,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv3 = nn.Conv2d(in_channels=3,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv4 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv5 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv6 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

    def forward(self,secret_image):
        output_1 = F.relu(self.conv1(secret_image))
        output_2 = F.relu(self.conv2(secret_image))
        output_3 = F.relu(self.conv3(secret_image))

        concatenated_image = torch.cat([output_1,output_2,output_3],dim=1)
        output_4 = F.relu(self.conv4(concatenated_image))
        output_5 = F.relu(self.conv5(concatenated_image))
        output_6 = F.relu(self.conv6(concatenated_image))

        final_concat_image = torch.cat([output_4,output_5,output_6],dim=1)
        return final_concat_image

class PrepNetwork3(nn.Module):
    def __init__(self):
        super(PrepNetwork3, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv2 = nn.Conv2d(in_channels=3,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv3 = nn.Conv2d(in_channels=3,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv4 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv5 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv6 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

    def forward(self,secret_image):
        output_1 = F.relu(self.conv1(secret_image))
        output_2 = F.relu(self.conv2(secret_image))
        output_3 = F.relu(self.conv3(secret_image))

        concatenated_image = torch.cat([output_1,output_2,output_3],dim=1)
        output_4 = F.relu(self.conv4(concatenated_image))
        output_5 = F.relu(self.conv5(concatenated_image))
        output_6 = F.relu(self.conv6(concatenated_image))

        final_concat_image = torch.cat([output_4,output_5,output_6],dim=1)
        return final_concat_image

class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=198,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv2 = nn.Conv2d(in_channels=198,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv3 = nn.Conv2d(in_channels=198,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv4 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv5 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv6 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv7 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv8 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv9 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv10 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv11 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv12 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv13 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv14 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv15 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.final_layer = nn.Conv2d(in_channels=65,out_channels=3,kernel_size=(3,3),stride=1,padding=1)

    def forward(self,secret_image_1,secret_image_2,secret_image_3,cover_image):
        concatenated_secrets = torch.cat([cover_image,secret_image_1,secret_image_2,secret_image_3],dim=1)

        output_1 = F.relu(self.conv1(concatenated_secrets))
        output_2 = F.relu(self.conv2(concatenated_secrets))
        output_3 = F.relu(self.conv3(concatenated_secrets))
        concat_1 = torch.cat([output_1,output_2,output_3],dim=1)

        output_4 = F.relu(self.conv4(concat_1))
        output_5 = F.relu(self.conv5(concat_1))
        output_6 = F.relu(self.conv6(concat_1))
        concat_2 = torch.cat([output_4,output_5,output_6],dim=1)

        output_7 = F.relu(self.conv7(concat_2))
        output_8 = F.relu(self.conv8(concat_2))
        output_9 = F.relu(self.conv9(concat_2))
        concat_3 = torch.cat([output_7,output_8,output_9],dim=1)

        output_10 = F.relu(self.conv10(concat_3))
        output_11 = F.relu(self.conv11(concat_3))
        output_12 = F.relu(self.conv12(concat_3))
        concat_4 = torch.cat([output_10,output_11,output_12],dim=1)

        output_13 = F.relu(self.conv13(concat_4))
        output_14 = F.relu(self.conv14(concat_4))
        output_15 = F.relu(self.conv15(concat_4))
        concat_5 = torch.cat([output_13,output_14,output_15],dim=1)

        output_converted_image = F.relu(self.final_layer(concat_5))

        return output_converted_image

# %%
class Encoder(nn.Module):
    def __init__(self,prep_network_1,prep_network_2,prep_network_3,hiding_network):
        super(Encoder, self).__init__()
        self.prep_network1 = prep_network_1
        self.prep_network2 = prep_network_2
        self.prep_network3 = prep_network_3
        self.hiding_network = hiding_network

    def forward(self,cover_image,secret_image_1,secret_image_2,secret_image_3):
        encoded_secret_image_1 = self.prep_network1(secret_image_1)
        encoded_secret_image_2 = self.prep_network2(secret_image_2)
        encoded_secret_image_3 = self.prep_network3(secret_image_3)

        hidden_image = self.hiding_network(encoded_secret_image_1,
                                           encoded_secret_image_2,
                                           encoded_secret_image_3,
                                           cover_image
                                          )
#         hidden_image = (0.01**0.5)*torch.randn(hidden_image.size(),device=device)
        return hidden_image

# %%
class RevealNetwork1(nn.Module):
    def __init__(self):
        super(RevealNetwork1,self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv2 = nn.Conv2d(in_channels=3,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv3 = nn.Conv2d(in_channels=3,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv4 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv5 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv6 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv7 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv8 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv9 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv10 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv11 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv12 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv13 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv14 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv15 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.final_layer = nn.Conv2d(in_channels=65,out_channels=3,kernel_size=(3,3),stride=1,padding=1)

    def forward(self,hidden_image):

        output_1 = F.relu(self.conv1(hidden_image))
        output_2 = F.relu(self.conv2(hidden_image))
        output_3 = F.relu(self.conv3(hidden_image))
        concat_1 = torch.cat([output_1,output_2,output_3],dim=1)

        output_4 = F.relu(self.conv4(concat_1))
        output_5 = F.relu(self.conv5(concat_1))
        output_6 = F.relu(self.conv6(concat_1))
        concat_2 = torch.cat([output_4,output_5,output_6],dim=1)

        output_7 = F.relu(self.conv7(concat_2))
        output_8 = F.relu(self.conv8(concat_2))
        output_9 = F.relu(self.conv9(concat_2))
        concat_3 = torch.cat([output_7,output_8,output_9],dim=1)

        output_10 = F.relu(self.conv10(concat_3))
        output_11 = F.relu(self.conv11(concat_3))
        output_12 = F.relu(self.conv12(concat_3))
        concat_4 = torch.cat([output_10,output_11,output_12],dim=1)

        output_13 = F.relu(self.conv13(concat_4))
        output_14 = F.relu(self.conv14(concat_4))
        output_15 = F.relu(self.conv15(concat_4))
        concat_5 = torch.cat([output_13,output_14,output_15],dim=1)

        output_revealed_image = F.relu(self.final_layer(concat_5))

        return output_revealed_image

class RevealNetwork2(nn.Module):
    def __init__(self):
        super(RevealNetwork2,self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv2 = nn.Conv2d(in_channels=3,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv3 = nn.Conv2d(in_channels=3,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv4 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv5 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv6 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv7 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv8 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv9 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv10 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv11 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv12 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv13 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv14 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv15 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.final_layer = nn.Conv2d(in_channels=65,out_channels=3,kernel_size=(3,3),stride=1,padding=1)

    def forward(self,hidden_image):

        output_1 = F.relu(self.conv1(hidden_image))
        output_2 = F.relu(self.conv2(hidden_image))
        output_3 = F.relu(self.conv3(hidden_image))
        concat_1 = torch.cat([output_1,output_2,output_3],dim=1)

        output_4 = F.relu(self.conv4(concat_1))
        output_5 = F.relu(self.conv5(concat_1))
        output_6 = F.relu(self.conv6(concat_1))
        concat_2 = torch.cat([output_4,output_5,output_6],dim=1)

        output_7 = F.relu(self.conv7(concat_2))
        output_8 = F.relu(self.conv8(concat_2))
        output_9 = F.relu(self.conv9(concat_2))
        concat_3 = torch.cat([output_7,output_8,output_9],dim=1)

        output_10 = F.relu(self.conv10(concat_3))
        output_11 = F.relu(self.conv11(concat_3))
        output_12 = F.relu(self.conv12(concat_3))
        concat_4 = torch.cat([output_10,output_11,output_12],dim=1)

        output_13 = F.relu(self.conv13(concat_4))
        output_14 = F.relu(self.conv14(concat_4))
        output_15 = F.relu(self.conv15(concat_4))
        concat_5 = torch.cat([output_13,output_14,output_15],dim=1)

        output_revealed_image = F.relu(self.final_layer(concat_5))

        return output_revealed_image

class RevealNetwork3(nn.Module):
    def __init__(self):
        super(RevealNetwork3,self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv2 = nn.Conv2d(in_channels=3,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv3 = nn.Conv2d(in_channels=3,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv4 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv5 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv6 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv7 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv8 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv9 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv10 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv11 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv12 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.conv13 = nn.Conv2d(in_channels=65,out_channels=50,kernel_size=(3,3),stride=1,padding=1)
        self.conv14 = nn.Conv2d(in_channels=65,out_channels=10,kernel_size=(3,3),stride=1,padding=1)
        self.conv15 = nn.Conv2d(in_channels=65,out_channels=5,kernel_size=(5,5),stride=1,padding=2)

        self.final_layer = nn.Conv2d(in_channels=65,out_channels=3,kernel_size=(3,3),stride=1,padding=1)

    def forward(self,hidden_image):
        output_1 = F.relu(self.conv1(hidden_image))
        output_2 = F.relu(self.conv2(hidden_image))
        output_3 = F.relu(self.conv3(hidden_image))
        concat_1 = torch.cat([output_1,output_2,output_3],dim=1)

        output_4 = F.relu(self.conv4(concat_1))
        output_5 = F.relu(self.conv5(concat_1))
        output_6 = F.relu(self.conv6(concat_1))
        concat_2 = torch.cat([output_4,output_5,output_6],dim=1)

        output_7 = F.relu(self.conv7(concat_2))
        output_8 = F.relu(self.conv8(concat_2))
        output_9 = F.relu(self.conv9(concat_2))
        concat_3 = torch.cat([output_7,output_8,output_9],dim=1)

        output_10 = F.relu(self.conv10(concat_3))
        output_11 = F.relu(self.conv11(concat_3))
        output_12 = F.relu(self.conv12(concat_3))
        concat_4 = torch.cat([output_10,output_11,output_12],dim=1)

        output_13 = F.relu(self.conv13(concat_4))
        output_14 = F.relu(self.conv14(concat_4))
        output_15 = F.relu(self.conv15(concat_4))
        concat_5 = torch.cat([output_13,output_14,output_15],dim=1)

        output_revealed_image = F.relu(self.final_layer(concat_5))

        return output_revealed_image

# %%
class Decoder(nn.Module):
    def __init__(self,reveal_network_1,reveal_network_2,reveal_network_3):
        super(Decoder, self).__init__()
        self.reveal_network_1 = reveal_network_1
        self.reveal_network_2 = reveal_network_2
        self.reveal_network_3 = reveal_network_3

    def forward(self,hidden_image):
        reveal_image_1 = self.reveal_network_1(hidden_image)
        reveal_image_2 = self.reveal_network_2(hidden_image)
        reveal_image_3 = self.reveal_network_3(hidden_image)
        return reveal_image_1,reveal_image_2,reveal_image_3

# %%
class SteganoModel(nn.Module):
    def __init__(self,encoder,decoder):
        super(SteganoModel,self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self,cover_image,secret_image_1,secret_image_2,secret_image_3,hidden_image,mode):
        if mode == 'full':
            for param in self.encoder.parameters():
                param.requires_grad = True
            for param in self.decoder.parameters():
                param.requires_grad = False
            hidden_image = self.encoder(cover_image,secret_image_1,secret_image_2,secret_image_3)
            reveal_image_1,reveal_image_2,reveal_image_3 = self.decoder(hidden_image)
            return hidden_image,reveal_image_1,reveal_image_2,reveal_image_3
        elif mode == 'encoder':
            for param in self.encoder.parameters():
                param.requires_grad = False
            for param in self.decoder.parameters():
                param.requires_grad = False
            hidden_image = self.encoder(cover_image,secret_image_1,secret_image_2,secret_image_3)
            return hidden_image
        elif mode == 'decoder':
            for param in self.encoder.parameters():
                param.requires_grad = False
            for param in self.decoder.parameters():
                param.requires_grad = True

            reveal_image1, reveal_image2,reveal_image3 = self.decoder(hidden_image)
            return reveal_image1, reveal_image2,reveal_image3

# %%
prep_1 = PrepNetwork1()
prep_2 = PrepNetwork2()
prep_3 = PrepNetwork3()
hiding_network = HidingNetwork()

encoder = Encoder(prep_1,prep_2,prep_3,hiding_network)

reveal_1 = RevealNetwork1()
reveal_2 = RevealNetwork2()
reveal_3 = RevealNetwork3()

decoder = Decoder(reveal_1,reveal_2,reveal_3)

model = SteganoModel(encoder,decoder)
model.to(device)
# Out:
# SteganoModel(
#   (encoder): Encoder(
#     (prep_network1): PrepNetwork1(
#       (conv1): Conv2d(3, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(3, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv4): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv5): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv6): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (prep_network2): PrepNetwork2(
#       (conv1): Conv2d(3, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(3, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv4): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv5): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv6): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (prep_network3): PrepNetwork3(
#       (conv1): Conv2d(3, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(3, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv4): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv5): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv6): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (hiding_network): HidingNetwork(
#       (conv1): Conv2d(198, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(198, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(198, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv4): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv5): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv6): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv7): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv8): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv9): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv10): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv11): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv12): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv13): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv14): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv15): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (final_layer): Conv2d(65, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (decoder): Decoder(
#     (reveal_network_1): RevealNetwork1(
#       (conv1): Conv2d(3, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(3, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv4): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv5): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv6): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv7): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv8): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv9): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv10): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv11): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv12): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv13): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv14): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv15): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (final_layer): Conv2d(65, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (reveal_network_2): RevealNetwork2(
#       (conv1): Conv2d(3, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(3, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv4): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv5): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv6): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv7): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv8): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv9): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv10): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv11): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv12): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv13): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv14): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv15): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (final_layer): Conv2d(65, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (reveal_network_3): RevealNetwork3(
#       (conv1): Conv2d(3, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(3, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv4): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv5): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv6): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv7): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv8): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv9): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv10): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv11): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv12): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (conv13): Conv2d(65, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv14): Conv2d(65, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv15): Conv2d(65, 5, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (final_layer): Conv2d(65, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
# )

# %%
class SteganoLoss(nn.Module):
    def __init__(self,cover_weight,secret_weight):
        super(SteganoLoss,self).__init__()
        self.cover_weight = cover_weight
        self.secret_weight = secret_weight

    def forward(self,predicted_cover_image,cover_image,
               predicted_secret_image_1,secret_image_1,
               predicted_secret_image_2,secret_image_2,
               predicted_secret_image_3,secret_image_3):

        cover_loss = self.cover_weight*(F.mse_loss(predicted_cover_image,cover_image))
        secret_loss = self.secret_weight*(F.mse_loss(predicted_secret_image_1,secret_image_1)) + self.secret_weight*(F.mse_loss(predicted_secret_image_2,secret_image_2)) + self.secret_weight*(F.mse_loss(predicted_secret_image_3,secret_image_3))
        return cover_loss + secret_loss

class DecoderLoss(nn.Module):
    def __init__(self,decoder_loss_weight):
        super(DecoderLoss,self).__init__()
        self.decoder_loss_weight = decoder_loss_weight

    def forward(self,reveal_output1, reveal_output2,reveal_output3,secret_image_1,
                                            secret_image_2,secret_image_3):
        reveal1 = self.decoder_loss_weight*F.mse_loss(reveal_output1,secret_image_1)
        reveal2 = self.decoder_loss_weight*F.mse_loss(reveal_output2,secret_image_2)
        reveal3 = self.decoder_loss_weight*F.mse_loss(reveal_output3,secret_image_3)

        return reveal1 + reveal2 + reveal3

# %%
# !ls /content/dataset/validation_dataset.csv
# Out:
# /content/dataset/validation_dataset.csv

# %%
training_csv_path = os.path.join(dataset_path,train_csv)
validation_csv_path = os.path.join(dataset_path,valid_csv)


#training_dataset = SteganoDataset(training_csv_path,transformations['train_transforms'],'train','complete')
valid_dataset = SteganoDataset(validation_csv_path,transformations['valid_transforms'],'valid')

#train_data_loader = torch.utils.data.DataLoader(training_dataset,
                                                #batch_size = TRAIN_BATCH_SIZE,
                                                #shuffle=True,
                                                #drop_last = True,
                                                #num_workers = 0
                                               #)
valid_data_loader = torch.utils.data.DataLoader(valid_dataset,
                                                batch_size = VALID_BATCH_SIZE,
                                                shuffle=True,
                                                drop_last = True,
                                                num_workers = 0
                                               )

full_model_criterion = SteganoLoss(SECRET_LOSS_WEIGHT,COVER_LOSS_WEIGHT)

full_model_optimizer = torch.optim.Adam(model.parameters(),lr=LEARNING_RATE)

decoder_criterion = DecoderLoss(DECODER_LOSS_WEIGHT)

# %%
def train(model,epochs,decoder_criterion,full_model_optimizer,full_model_criterion,learning_rate,training_iterator,valid_iterator,print_every=50):

    training_full_model_loss_list = []
    decoder_loss_list = []
    valid_loss_list = []

    for epoch in range(epochs):
        for index,training_dict in enumerate(training_iterator):
            cover_image = training_dict['cover_image']
            cover_image = cover_image.to(device)

            secret_image_1 = training_dict['secret_image_1']
            secret_image_1 = secret_image_1.to(device)

            secret_image_2 = training_dict['secret_image_2']
            secret_image_2 = secret_image_2.to(device)

            secret_image_3 = training_dict['secret_image_3']
            secret_image_3 = secret_image_3.to(device)

            full_model_optimizer.zero_grad()

            encoder_output = model(cover_image,secret_image_1,secret_image_2,secret_image_3,secret_image_3,'encoder')

            hidden_image,reveal_image_1,reveal_image_2,reveal_image_3 = model(cover_image,
                                                                 secret_image_1,
                                                                 secret_image_2,
                                                                 secret_image_3,secret_image_3,'full')

            full_model_loss = full_model_criterion(hidden_image,cover_image,
                             reveal_image_1,secret_image_1,
                             reveal_image_2,secret_image_2,
                             reveal_image_3,secret_image_3,
                            )
            full_model_loss.backward()
            full_model_optimizer.step()

            full_model_optimizer.zero_grad()
            reveal_output1, reveal_output2,reveal_output3 = model(cover_image,
                                                                 secret_image_1,
                                                                 secret_image_2,
                                                                 secret_image_3,encoder_output,'decoder')
            decoder_loss = decoder_criterion(reveal_output1, reveal_output2,reveal_output3,secret_image_1,
                                            secret_image_2,secret_image_3)

            decoder_loss.backward()
            full_model_optimizer.step()

        training_full_model_loss_list.append(full_model_loss)
        decoder_loss_list.append(decoder_loss)
        if epoch % print_every == 0:
            print("Training full model loss at {} epochs is: {}".format(epoch, full_model_loss))
            print("Training decoder loss at {} epochs is: {}".format(epoch, decoder_loss))

    return model, training_full_model_loss_list,decoder_loss_list

# %%
model, training_full_model_loss_list,decoder_loss_list = train(model,EPOCHS,decoder_criterion,full_model_optimizer,full_model_criterion,LEARNING_RATE,train_data_loader,valid_data_loader)
# Out:
# Training full model loss at 0 epochs is: 0.3847321569919586
# Training decoder loss at 0 epochs is: 0.34206676483154297
# Training full model loss at 50 epochs is: 0.06924165040254593
# Training decoder loss at 50 epochs is: 0.04892994463443756
# Training full model loss at 100 epochs is: 0.05085470527410507
# Training decoder loss at 100 epochs is: 0.03802792355418205
# Training full model loss at 150 epochs is: 0.03637094795703888
# Training decoder loss at 150 epochs is: 0.02620428055524826
# Training full model loss at 200 epochs is: 0.026935387402772903
# Training decoder loss at 200 epochs is: 0.0216311477124691
# Training full model loss at 250 epochs is: 0.02079840563237667
# Training decoder loss at 250 epochs is: 0.01709096133708954
# Training full model loss at 300 epochs is: 0.020048968493938446
# Training decoder loss at 300 epochs is: 0.0165126733481884
# Training full model loss at 350 epochs is: 0.02106284722685814
# Training decoder loss at 350 epochs is: 0.017230628058314323
# Training full model loss at 400 epochs is: 0.017332490533590317
# Training decoder loss at 400 epochs is: 0.014671532437205315
# Training full model loss at 450 epochs is: 0.015750763937830925
# Training decoder loss at 450 epochs is: 0.013828577473759651
# Training full model loss at 500 epochs is: 0.0179778803139925
# Training decoder loss at 500 epochs is: 0.01598471775650978
# Training full model loss at 550 epochs is: 0.01685965061187744
# Training decoder loss at 550 epochs is: 0.014580857008695602
# Training full model loss at 600 epochs is: 0.01482556201517582
# Training decoder loss at 600 epochs is: 0.011749432422220707
# Training full model loss at 650 epochs is: 0.01871069148182869
# Training decoder loss at 650 epochs is: 0.01585376262664795
# Training full model loss at 700 epochs is: 0.01610180363059044
# Training decoder loss at 700 epochs is: 0.014263918623328209
# Training full model loss at 750 epochs is: 0.013286678120493889
# Training decoder loss at 750 epochs is: 0.01102739479392767
# Training full model loss at 800 epochs is: 0.014665328897535801
# Training decoder loss at 800 epochs is: 0.012630688026547432
# Training full model loss at 850 epochs is: 0.014037946239113808
# Training decoder loss at 850 epochs is: 0.011997831985354424
# Training full model loss at 900 epochs is: 0.01359646674245596
# Training decoder loss at 900 epochs is: 0.011750774458050728
# Training full model loss at 950 epochs is: 0.013683628290891647
# Training decoder loss at 950 epochs is: 0.01201759185642004

# %%
model = torch.load('/content/drive/MyDrive/model_1000.pkl',map_location=torch.device('cpu'))
torch.save(model,'./model_1000.pkl')

# %%
data = next(iter(valid_data_loader))

cover_image = data['cover_image']
cover_image = cover_image.to(device)

secret_image_1 = data['secret_image_1']
secret_image_1 = secret_image_1.to(device)

secret_image_2 = data['secret_image_2']
secret_image_2 = secret_image_2.to(device)

secret_image_3 = data['secret_image_3']
secret_image_3 = secret_image_3.to(device)

model.eval()

hidden_image,reveal_image_1,reveal_image_2,reveal_image_3 = model(cover_image,
                                                                 secret_image_1,
                                                                 secret_image_2,
                                                                 secret_image_3,secret_image_3,'full')

# %%
make_dot(hidden_image).render('hidden_image',format='png')
# Out:
# 'hidden_image.png'

# %%
make_dot(reveal_image_1).render('reveal_image',format='png')
# Out:
# 'reveal_image.png'

# %%
def plot_loss(loss_list,title):
    plt.plot(loss_list)
    plt.show()

# %%
plot_loss(training_full_model_loss_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-36674d167399> in <cell line: 1>()
# ----> 1 plot_loss(training_full_model_loss_list)
#
# NameError: name 'training_full_model_loss_list' is not defined

# %%
plot_loss(decoder_loss_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-6d3392b7b0a4> in <cell line: 1>()
# ----> 1 plot_loss(decoder_loss_list)
#
# NameError: name 'decoder_loss_list' is not defined

# %%
def predict(model,iterator):
    predict_dict = next(iter(iterator))
    cover_image = predict_dict['cover_image']
    cover_image = cover_image.to(device)

    secret_image_1 = predict_dict['secret_image_1']
    secret_image_1 = secret_image_1.to(device)

    secret_image_2 = predict_dict['secret_image_2']
    secret_image_2 = secret_image_2.to(device)

    secret_image_3 = predict_dict['secret_image_3']
    secret_image_3 = secret_image_3.to(device)

    model.eval()

    hidden_image,reveal_image_1,reveal_image_2,reveal_image_3 = model(cover_image,
                                                                 secret_image_1,
                                                                 secret_image_2,
                                                                 secret_image_3,secret_image_3,'full')

    cover_image = cover_image * 255
    secret_image_3 = secret_image_3 * 255
    secret_image_1 = secret_image_1 * 255
    secret_image_2 = secret_image_2 * 255

    hidden_image = hidden_image * 255
    reveal_image_1 = reveal_image_1 * 255
    reveal_image_2 = reveal_image_2 * 255
    reveal_image_3 = reveal_image_3 * 255

    secret_image_1 = secret_image_1.to(torch.device('cpu'))
    secret_image_2 = secret_image_2.to(torch.device('cpu'))
    secret_image_3 = secret_image_3.to(torch.device('cpu'))
    cover_image = cover_image.to(torch.device('cpu'))

    reveal_image_1 = reveal_image_1.to(torch.device('cpu'))
    reveal_image_2 = reveal_image_2.to(torch.device('cpu'))
    reveal_image_3 = reveal_image_3.to(torch.device('cpu'))
    hidden_image = hidden_image.to(torch.device('cpu'))

    secret_image_1 = secret_image_1.detach().to(torch.long)
    secret_image_2 = secret_image_2.detach().to(torch.long)
    secret_image_3 = secret_image_3.detach().to(torch.long)
    cover_image = cover_image.detach().to(torch.long)

    hidden_image = hidden_image.detach().to(torch.long)
    reveal_image_1 = reveal_image_1.detach().to(torch.long)
    reveal_image_2 = reveal_image_2.detach().to(torch.long)
    reveal_image_3 = reveal_image_3.detach().to(torch.long)


    hidden_image_grid = torchvision.utils.make_grid(hidden_image,nrow=4)
    reveal_image_1_grid = torchvision.utils.make_grid(reveal_image_1,nrow=4)
    reveal_image_2_grid = torchvision.utils.make_grid(reveal_image_2,nrow=4)
    reveal_image_3_grid = torchvision.utils.make_grid(reveal_image_3,nrow=4)

    cover_image_grid = torchvision.utils.make_grid(cover_image,nrow=4)
    secret_image_1_grid = torchvision.utils.make_grid(secret_image_1,nrow=4)
    secret_image_2_grid = torchvision.utils.make_grid(secret_image_2,nrow=4)
    secret_image_3_grid = torchvision.utils.make_grid(secret_image_3,nrow=4)
    return {
        'cover_image_grid':cover_image_grid,
        'secret_image_1_grid':secret_image_1_grid,
        'secret_image_2_grid':secret_image_2_grid,
        'secret_image_3_grid':secret_image_3_grid,
        'hidden_image_grid':hidden_image_grid,
        'reveal_image_1_grid':reveal_image_1_grid,
        'reveal_image_2_grid':reveal_image_2_grid,
        'reveal_image_3_grid':reveal_image_3_grid
    }

# %%
grids = predict(model,valid_data_loader)

# %%
def plot_encrypt(grids):
    plt.figure(figsize=(15,8))

    plt.subplot(241)
    plt.title('Cover Image')
    plt.imshow(grids['cover_image_grid'].permute(1,2,0))

    plt.subplot(242)
    plt.title('Secret Image 1')
    plt.imshow(grids['secret_image_1_grid'].permute(1,2,0))

    plt.subplot(243)
    plt.title('Secret Image 2')
    plt.imshow(grids['secret_image_2_grid'].permute(1,2,0))

    plt.subplot(244)
    plt.title('Secret Image 3')
    plt.imshow(grids['secret_image_3_grid'].permute(1,2,0))

    plt.show()

# %%
def plot_decrypt(grids):
    plt.figure(figsize=(15,8))
    plt.subplot(245)
    plt.title('Hidden Image')
    plt.imshow(grids['hidden_image_grid'].permute(1,2,0))

    plt.subplot(246)
    plt.title('Reveal Image 1')
    plt.imshow(grids['reveal_image_1_grid'].permute(1,2,0))

    plt.subplot(247)
    plt.title('Reveal Image 2')
    plt.imshow(grids['reveal_image_2_grid'].permute(1,2,0))

    plt.subplot(248)
    plt.title('Reveal Image 3')
    plt.imshow(grids['reveal_image_3_grid'].permute(1,2,0))

    plt.show()

# %%
plot_encrypt(grids)

# %%
plot_decrypt(grids)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
for i in range(5):
    grids = predict(model,valid_data_loader)
    plot_encrypt(grids)
    plot_decrypt(grids)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
